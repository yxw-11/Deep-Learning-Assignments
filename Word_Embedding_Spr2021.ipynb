# %% [markdown]
# # Word Embeddings
#
# In this notebook, you will implement 2 algorithms for learning word embeddings. You will use these algorithms to measure semantic similarity between words.

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

## Standard Library
import random
from string import punctuation
from collections import Counter

## External Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_distances
from sklearn.datasets import fetch_20newsgroups
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
import gensim.downloader

# PyTorch Modules: see http://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)
print("GPU Available:", torch.cuda.is_available())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# GPU Available: True

# %%
## Simple Plotting Utility
def showPlot(title, *args):
    plt.figure()
    fig, ax = plt.subplots()
    for a in args:
      _ = ax.plot(a)
    _ = ax.set_title(title)

# %%
def tokenize(text):
    """
    Simple tokenizer (sentences and then words)
    """
    sentences = sent_tokenize(text)
    examples = []
    for sentence in sentences:
        sentence = "".join(char for char in sentence if char not in punctuation)
        sentence = "".join(char for char in sentence if not char.isdigit())
        sentence = sentence.lower()
        tokens = word_tokenize(sentence)
        examples.append(tokens)
    return examples

tokenize("Why, hello there! What's your name?")
# Out:
# [['why', 'hello', 'there'], ['whats', 'your', 'name']]

# %% [markdown]
# ### Data
#
# We provide two datasets. Use the small dataset to develop your algorithms and test semantic similarity at the end of the notebook. Use the larger dataset once your models are developed to get a sense for the scalability of your approaches.
#
# Please include visualizations of the train/test loss for both datasets. For the small dataset, please train your models for 1000 epochs. For the large dataset, please train your models for at least 100 epochs.

# %%
# Text is lightly adapted (removing punctuation and possesives) from The Raven by Edgar Allan Poe
text_small = [""" Once upon a midnight dreary while I pondered weak and weary
 Over many a quaint and curious volume of forgotten lore
 While I nodded nearly napping suddenly there came a tapping
 As of some one gently rapping rapping at my chamber door
 This is some visiter I muttered tapping at my chamber door
                          Only this and nothing more

 Ah distinctly I remember it was in the bleak December
 And each separate dying ember wrought its ghost upon the floor
 Eagerly I wished the morrow vainly I had sought to borrow
 From my books surcease of sorrow sorrow for the lost Lenore
 For the rare and radiant maiden whom the angels name Lenore
                          Nameless here for evermore

 And the silken sad uncertain rustling of each purple curtain
 Thrilled me filled me with fantastic terrors never felt before
 So that now to still the beating of my heart I stood repeating
 This is some visiter entreating entrance at my chamber door
 Some late visiter entreating entrance at my chamber door
                          This it is and nothing more

 Presently my soul grew stronger hesitating then no longer
 Sir said I or Madam truly your forgiveness I implore
 But the fact is I was napping and so gently you came rapping
 And so faintly you came tapping tapping at my chamber door
 That I scarce was sure I heard you here I opened wide the door
                          Darkness there and nothing more

 Deep into that darkness peering long I stood there wondering fearing
 Doubting dreaming dreams no mortal ever dared to dream before
 But the silence was unbroken and the darkness gave no token
 And the only word there spoken was the whispered word Lenore
 This I whispered and an echo murmured back the word Lenore
                          Merely this and nothing more

 Back into the chamber turning all my soul within me burning
 Soon I heard again a tapping somewhat louder than before
 Surely said I surely that is something at my window lattice
 Let me see then what thereat is and this mystery explore
 Let my heart be still a moment and this mystery explore
                          This is the wind and nothing more

 Open here I flung the shutter when with many a flirt and flutter
 In there stepped a stately raven of the saintly days of yore
 Not the least obeisance made he not an instant stopped or stayed he
 But with mien of lord or lady perched above my chamber door
 Perched upon a bust of Pallas just above my chamber door
                          Perched and sat and nothing more

 Then this ebony bird beguiling my sad fancy into smiling
 By the grave and stern decorum of the countenance it wore
 Though thy crest be shorn and shaven thou I said art sure no craven
 Ghastly grim and ancient raven wandering from the Nightly shore
 Tell me what thy lordly name is on the Night Plutonian shore
                          Quoth the raven Nevermore

 Much I marvelled this ungainly fowl to hear discourse so plainly
 Though its answer little meaninglittle relevancy bore
 For we cannot help agreeing that no living human being
 Ever yet was blessed with seeing bird above his chamber door
 Bird or beast upon the sculptured bust above his chamber door
                         With such name as Nevermore

 But the raven sitting lonely on the placid bust spoke only
 That one word as if his soul in that one word he did outpour
 Nothing farther then he utterednot a feather then he fluttered
 Till I scarcely more than muttered Other friends have flown before
 On the morrow he will leave me as my hopes have flown before
                          Then the bird said Nevermore

 Startled at the stillness broken by reply so aptly spoken
 Doubtless said I what it utters is its only stock and store
 Caught from some unhappy master whom unmerciful Disaster
 Followed fast and followed faster till his songs one burden bore
 Till the dirges of his Hope that melancholy burden bore
                         Of Never nevermore

 But the raven still beguiling all my sad soul into smiling
 Straight I wheeled a cushioned seat in front of bird and bust and door
 Then upon the velvet sinking I betook myself to thinking
 Fancy unto fancy thinking what this ominous bird of yore
 What this grim ungainly ghastly gaunt and ominous bird of yore
                         Meant in croaking Nevermore

 This I sat engaged in guessing but no syllable expressing
 To the fowl whose fiery eyes now burned into my bosom core
 This and more I sat divining with my head at ease reclining
 On the cushion velvet lining that the lamplght gloated over
 But whose velvet violet lining with the lamplight gloating over
                          She shall press ah nevermore

 Then me thought the air grew denser perfumed from an unseen censer
 Swung by Angels whose faint foot-falls tinkled on the tufted floor
 Wretch I cried thy God hath lent theeby these angels he hath sent
 thee
 Respite respite and nepenthe from thy memories of Lenore
 Quaff oh quaff this kind nepenthe and forget this lost Lenore
                           Quoth the raven Nevermore

 Prophet said I thing of evil prophet still if bird or devil
 Whether Tempter sent or whether tempest tossed thee here ashore
 Desolate yet all undaunted on this desert land enchanted
 On this home by Horror haunted tell me truly I implore
 Is there is there balm in Gilead tell me tell me I implore
                           Quoth the raven Nevermore

 Prophet said I thing of evil prophet still if bird or devil
 By that Heaven that bends above us by that God we both adore
 Tell this soul with sorrow laden if within the distant Aidenn
 It shall clasp a sainted maiden whom the angels name Lenore
 Clasp a rare and radiant maiden whom the angels name Lenore
                           Quoth the raven Nevermore

 Be that word our sign of parting bird or fiend I shrieked upstarting
 Get thee back into the tempest and the Night Plutonian shore
 Leave no black plume as a token of that lie thy soul hath spoken
 Leave my loneliness unbroken quit the bust above my door
 Take thy beak from out my heart and take thy form from off my door
                          Quoth the raven Nevermore

 And the raven never flitting still is sitting still is sitting
 On the pallid bust of Pallas just above my chamber door
 And his eyes have all the seeming of a demon that is dreaming
 And the lamp-light over him streaming throws his shadow on the floor
 And my soul from out that shadow that lies floating on the floor
                          Shall be lifted nevermore"""]

# %%
## Retrieve/Load Data
data = fetch_20newsgroups(subset="test", ## Choose Test Since Full Dataset Will Take Significant Training Time                         
                          remove=("headers","footers","quotes"),
                          data_home="./data/",
                          download_if_missing=True,
                          shuffle=False)

## Isolate Data
text_large = data.data
labels = data.target

## Show Sample Newsgroups Data
show = lambda i: print(text_large[i], "\n", tokenize(text_large[i]))
show(30)
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# It wasn't Jesus who changed the rules of the game (see quote above),
# it was Paul.
#
# Cheers,
# Kent
#
#  [['it', 'wasnt', 'jesus', 'who', 'changed', 'the', 'rules', 'of', 'the', 'game', 'see', 'quote', 'above', 'it', 'was', 'paul'], ['cheers', 'kent']]

# %%
## Tokenize Data (We Recommend Developing your model using text_small first)
documents = list(map(tokenize, text_small))
# documents = list(map(tokenize, text_large))

## Flatten Sentences
documents = [tokens for d in documents for tokens in d]
print("Dataset Size:", len(documents))
# Out:
# Dataset Size: 1

# %%
## Choose Frequency and Top Word Removal (Should Change This Depending on the Dataset)
MIN_FREQ = 0
RM_TOP = 0

## Get Vocabulary
vocab = [t for document in documents for t in document]
vocab_counts = Counter(vocab)
stopwords = set([s[0] for s in vocab_counts.most_common(RM_TOP)])
vocab = set([v for v in set(vocab) if vocab_counts[v] >= MIN_FREQ and v not in stopwords] + ["EOS"])
vocab_size = len(vocab)
print("Vocab Size:", vocab_size)

# Build a dictionary so that each word in vocabualary is assigned a number and 
# and we can map each number back to the word
w2i = {w: i for i, w in enumerate(sorted(vocab))}
i2w = {i: w for i, w in enumerate(sorted(vocab))}
# Out:
# Vocab Size: 435

# %%
## Update The Documents with OOV Token
documents = [list(filter(lambda token: token in vocab, document)) for document in documents]

## Sample Training And Test Documents
np.random.seed(1)
documents_train = documents_test = documents
if len(documents) > 1:
    train_ind, test_ind = train_test_split(list(range(len(documents))))
    documents_train = [documents[t] for t in train_ind]
    documents_test = [documents[t] for t in test_ind]

# %% [markdown]
# ![Continuous bag of words vs. skipgram model](https://raw.githubusercontent.com/jojonki/word2vec-pytorch/master/word2vec.PNG)
#
# Image from https://github.com/jojonki/word2vec-pytorch

# %% [markdown]
# ## CBOW Implementation
#
# Fill in the TODOs below.

# %%
## Choose Context Size
CONTEXT_SIZE = 2

# Tuple of an array of words (the context) to a word (the target)
def create_cbow_dataset(documents, context_size):
    data = []
    for document in documents:
        ## Pad the sentence
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        ## Get Context Tokens
        for i in range(context_size, len(document) - context_size):
            target = document[i]
            before_ctx = []
            after_ctx = []
            for j in range(1,context_size+1):
                before_ctx.append(document[i - j])
                after_ctx.append(document[i + j])
            context = before_ctx + after_ctx
            data.append((context, target))
    return data

## Generate Datasets
cbow_train = create_cbow_dataset(documents_train, context_size=CONTEXT_SIZE)
cbow_test = create_cbow_dataset(documents_test, context_size=CONTEXT_SIZE)

## Show Samples
print('cbow train samples')
for i in range(5):
    print(cbow_train[i])
print("total train samples", len(cbow_train))
print("total test samples", len(cbow_test))
# Out:
# cbow train samples
# (['EOS', 'EOS', 'upon', 'a'], 'once')
# (['once', 'EOS', 'a', 'midnight'], 'upon')
# (['upon', 'once', 'midnight', 'dreary'], 'a')
# (['a', 'upon', 'dreary', 'while'], 'midnight')
# (['midnight', 'a', 'while', 'i'], 'dreary')
# total train samples 1090
# total test samples 1090

# %%
## Example of the Dataset Generator
create_cbow_dataset([["hello","there","my","friend"]], 2)
# Out:
# [(['EOS', 'EOS', 'there', 'my'], 'hello'),
#  (['hello', 'EOS', 'my', 'friend'], 'there'),
#  (['there', 'hello', 'friend', 'EOS'], 'my'),
#  (['my', 'there', 'EOS', 'EOS'], 'friend')]

# %%
## Helper Function to Construct Batches of Examples
def get_cbow_batches(data, batch_size):
    """
    Generate batches of data for training CBOW Model
    """
    indices = np.arange(len(data))
    np.random.shuffle(indices)
    current_batch = []
    for i, indice in enumerate(indices):
        context, target = data[indice]
        ctx_idxs = [w2i[w] for w in context]
        ctx_var = torch.LongTensor(ctx_idxs)
        current_batch.append((ctx_var, torch.LongTensor([w2i[target]])))
        if current_batch and len(current_batch) % batch_size == 0 or i == len(indices) - 1:
            batch_context = torch.stack([v[0] for v in current_batch])
            batch_target = torch.stack([v[1] for v in current_batch])
            current_batch = []
            yield batch_context, batch_target

# %%
# Simple 3 layer network to map target word to an array of probabilities for 
# each word being in its context
# Note that the first layer is a special layer - an embedding layer 
# It maps the one-hot encoded vocabulary to a vector of a fixed size 
class CBOW(nn.Module):
    def __init__(self, vocab_size, embd_size, context_size, hidden_size):
        super(CBOW, self).__init__()
        #TODO implement layers show in the picture above
        self.embedding = nn.Embedding(vocab_size, embd_size)
        self.linear1 = nn.Linear(2 * context_size * embd_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        self.activation = nn.LogSoftmax(dim = -1)
    
    def forward(self, inputs):
        #TODO implement the forward of CBOW architecture
        embedded = self.embedding(inputs)
        embedded = embedded.view(embedded.shape[0], -1)
        hidden = F.relu(self.linear1(embedded))
        out = self.linear2(hidden)
        output = self.activation(out)
        
        return output

# %%
def train_cbow(train_data,
               test_data,
               model=None,
               n_epoch=1000,
               embd_size=100,
               learning_rate=0.01,
               context_size=CONTEXT_SIZE,
               batch_size=20,
               hidden_size=128,
               print_every=50,
               random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Batch size
    batch_size = min(batch_size, len(train_data))
    ## Initialize New Model if Not Using Existing
    if model is None:
        model = CBOW(vocab_size, embd_size, context_size, hidden_size)
    ## GPU
    gpu_avail = torch.cuda.is_available()
    if gpu_avail:
        model = model.cuda()
    ## Show the Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate loss function
    loss_fn = nn.NLLLoss()
    ## Cache for Loss Values
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        model.train()
        for batch, (context, target) in enumerate(get_cbow_batches(train_data, batch_size)):
            ##TODO implement training procedure for CBOW
            context = context.cuda()
            target = target.cuda()
            outputs = model(context)
            loss = loss_fn(outputs,target.squeeze())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
            total_loss += loss.item()
            
            if print_every is not None and (batch + 1) % print_every == 0:
                print("Epoch {} || batch {} || Loss: {:.4f}".format(epoch+1, batch+1, total_loss / (batch+1)))
        
        model.eval()
        ##TODO Compute Loss on Test and Training Data
        train_loss = total_loss / (batch+1)
        test_loss = 0
        for batch1, (context_t, target_t) in enumerate(get_cbow_batches(test_data, batch_size)):
            context_t = context_t.cuda()
            target_t = target_t.cuda()
            outputs_t = model(context_t)
            loss_t = loss_fn(outputs_t,target_t.squeeze())
            test_loss += loss_t.item()
        test_loss = test_loss / (batch1+1)
        print("Epoch {}/{} || Train Loss: {:.4f} || Test Loss: {:.4f}".format(epoch+1, n_epoch, train_loss, test_loss))
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete.")
    return model, losses, test_losses

## Train Model
cbow_model, cbow_losses, cbow_test_losses = train_cbow(cbow_train,
                                     cbow_test,
                                     model=None,
                                     n_epoch=1000,
                                     embd_size=100,
                                     context_size=CONTEXT_SIZE,
                                     batch_size=20,
                                     learning_rate=0.01,
                                     hidden_size=128,
                                     print_every=50)
# Out:
# CBOW(
#   (embedding): Embedding(435, 100)
#   (linear1): Linear(in_features=400, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=435, bias=True)
#   (activation): LogSoftmax(dim=-1)
# )
# Epoch 1 || batch 50 || Loss: 6.1055
# Epoch 1/1000 || Train Loss: 6.1065 || Test Loss: 6.0410
# Epoch 2 || batch 50 || Loss: 6.0267
# Epoch 2/1000 || Train Loss: 6.0199 || Test Loss: 5.9582
# Epoch 3 || batch 50 || Loss: 5.9430
# Epoch 3/1000 || Train Loss: 5.9399 || Test Loss: 5.8752
# Epoch 4 || batch 50 || Loss: 5.8559
# Epoch 4/1000 || Train Loss: 5.8562 || Test Loss: 5.7907
# Epoch 5 || batch 50 || Loss: 5.7709
# Epoch 5/1000 || Train Loss: 5.7693 || Test Loss: 5.7019
# Epoch 6 || batch 50 || Loss: 5.6822
# Epoch 6/1000 || Train Loss: 5.6808 || Test Loss: 5.6070
# Epoch 7 || batch 50 || Loss: 5.5902
# Epoch 7/1000 || Train Loss: 5.5866 || Test Loss: 5.5130
# Epoch 8 || batch 50 || Loss: 5.4902
# Epoch 8/1000 || Train Loss: 5.4831 || Test Loss: 5.4110
# Epoch 9 || batch 50 || Loss: 5.3834
# Epoch 9/1000 || Train Loss: 5.3824 || Test Loss: 5.3021
# Epoch 10 || batch 50 || Loss: 5.2800
# Epoch 10/1000 || Train Loss: 5.2670 || Test Loss: 5.1917
# Epoch 11 || batch 50 || Loss: 5.1646
# Epoch 11/1000 || Train Loss: 5.1591 || Test Loss: 5.0851
# Epoch 12 || batch 50 || Loss: 5.0442
# Epoch 12/1000 || Train Loss: 5.0625 || Test Loss: 4.9853
# Epoch 13 || batch 50 || Loss: 4.9657
# Epoch 13/1000 || Train Loss: 4.9621 || Test Loss: 4.8820
# Epoch 14 || batch 50 || Loss: 4.8655
# Epoch 14/1000 || Train Loss: 4.8699 || Test Loss: 4.7897
# Epoch 15 || batch 50 || Loss: 4.8001
# Epoch 15/1000 || Train Loss: 4.7817 || Test Loss: 4.7021
# Epoch 16 || batch 50 || Loss: 4.6746
# Epoch 16/1000 || Train Loss: 4.6882 || Test Loss: 4.6135
# Epoch 17 || batch 50 || Loss: 4.6105
# Epoch 17/1000 || Train Loss: 4.6027 || Test Loss: 4.5154
# Epoch 18 || batch 50 || Loss: 4.5122
# Epoch 18/1000 || Train Loss: 4.5222 || Test Loss: 4.4478
# Epoch 19 || batch 50 || Loss: 4.4407
# Epoch 19/1000 || Train Loss: 4.4346 || Test Loss: 4.3642
# Epoch 20 || batch 50 || Loss: 4.3330
# Epoch 20/1000 || Train Loss: 4.3557 || Test Loss: 4.2782
# Epoch 21 || batch 50 || Loss: 4.2436
# Epoch 21/1000 || Train Loss: 4.2759 || Test Loss: 4.2006
# Epoch 22 || batch 50 || Loss: 4.1917
# Epoch 22/1000 || Train Loss: 4.1891 || Test Loss: 4.1169
# Epoch 23 || batch 50 || Loss: 4.1247
# Epoch 23/1000 || Train Loss: 4.1201 || Test Loss: 4.0468
# Epoch 24 || batch 50 || Loss: 4.0580
# Epoch 24/1000 || Train Loss: 4.0359 || Test Loss: 3.9673
# Epoch 25 || batch 50 || Loss: 3.9484
# Epoch 25/1000 || Train Loss: 3.9602 || Test Loss: 3.8820
# Epoch 26 || batch 50 || Loss: 3.8887
# Epoch 26/1000 || Train Loss: 3.8758 || Test Loss: 3.8013
# Epoch 27 || batch 50 || Loss: 3.8000
# Epoch 27/1000 || Train Loss: 3.8046 || Test Loss: 3.7324
# Epoch 28 || batch 50 || Loss: 3.7697
# Epoch 28/1000 || Train Loss: 3.7245 || Test Loss: 3.6538
# Epoch 29 || batch 50 || Loss: 3.6412
# Epoch 29/1000 || Train Loss: 3.6624 || Test Loss: 3.5843
# Epoch 30 || batch 50 || Loss: 3.5784
# Epoch 30/1000 || Train Loss: 3.5846 || Test Loss: 3.5088
# Epoch 31 || batch 50 || Loss: 3.5031
# Epoch 31/1000 || Train Loss: 3.5118 || Test Loss: 3.4331
# Epoch 32 || batch 50 || Loss: 3.4496
# Epoch 32/1000 || Train Loss: 3.4389 || Test Loss: 3.3668
# Epoch 33 || batch 50 || Loss: 3.3688
# Epoch 33/1000 || Train Loss: 3.3615 || Test Loss: 3.3019
# Epoch 34 || batch 50 || Loss: 3.2790
# Epoch 34/1000 || Train Loss: 3.2998 || Test Loss: 3.2235
# Epoch 35 || batch 50 || Loss: 3.2073
# Epoch 35/1000 || Train Loss: 3.2183 || Test Loss: 3.1526
# Epoch 36 || batch 50 || Loss: 3.1520
# Epoch 36/1000 || Train Loss: 3.1483 || Test Loss: 3.0795
# Epoch 37 || batch 50 || Loss: 3.1088
# Epoch 37/1000 || Train Loss: 3.0741 || Test Loss: 3.0015
# Epoch 38 || batch 50 || Loss: 2.9748
# Epoch 38/1000 || Train Loss: 3.0172 || Test Loss: 2.9255
# Epoch 39 || batch 50 || Loss: 2.9232
# Epoch 39/1000 || Train Loss: 2.9486 || Test Loss: 2.8532
# Epoch 40 || batch 50 || Loss: 2.8756
# Epoch 40/1000 || Train Loss: 2.8712 || Test Loss: 2.7980
# Epoch 41 || batch 50 || Loss: 2.7899
# Epoch 41/1000 || Train Loss: 2.8074 || Test Loss: 2.7266
# Epoch 42 || batch 50 || Loss: 2.7505
# Epoch 42/1000 || Train Loss: 2.7191 || Test Loss: 2.6612
# Epoch 43 || batch 50 || Loss: 2.6757
# Epoch 43/1000 || Train Loss: 2.6637 || Test Loss: 2.5889
# Epoch 44 || batch 50 || Loss: 2.5763
# Epoch 44/1000 || Train Loss: 2.5990 || Test Loss: 2.5197
# Epoch 45 || batch 50 || Loss: 2.5259
# Epoch 45/1000 || Train Loss: 2.5276 || Test Loss: 2.4575
# Epoch 46 || batch 50 || Loss: 2.4489
# Epoch 46/1000 || Train Loss: 2.4542 || Test Loss: 2.3838
# Epoch 47 || batch 50 || Loss: 2.3795
# Epoch 47/1000 || Train Loss: 2.3886 || Test Loss: 2.3182
# Epoch 48 || batch 50 || Loss: 2.3114
# Epoch 48/1000 || Train Loss: 2.3248 || Test Loss: 2.2497
# Epoch 49 || batch 50 || Loss: 2.2464
# Epoch 49/1000 || Train Loss: 2.2638 || Test Loss: 2.1798
# Epoch 50 || batch 50 || Loss: 2.1707
# Epoch 50/1000 || Train Loss: 2.1986 || Test Loss: 2.1153
# Epoch 51 || batch 50 || Loss: 2.1255
# Epoch 51/1000 || Train Loss: 2.1266 || Test Loss: 2.0561
# Epoch 52 || batch 50 || Loss: 2.0418
# Epoch 52/1000 || Train Loss: 2.0686 || Test Loss: 1.9934
# Epoch 53 || batch 50 || Loss: 2.0280
# Epoch 53/1000 || Train Loss: 2.0017 || Test Loss: 1.9386
# Epoch 54 || batch 50 || Loss: 1.9552
# Epoch 54/1000 || Train Loss: 1.9339 || Test Loss: 1.8785
# Epoch 55 || batch 50 || Loss: 1.8592
# Epoch 55/1000 || Train Loss: 1.8803 || Test Loss: 1.8186
# Epoch 56 || batch 50 || Loss: 1.8448
# Epoch 56/1000 || Train Loss: 1.8181 || Test Loss: 1.7493
# Epoch 57 || batch 50 || Loss: 1.7766
# Epoch 57/1000 || Train Loss: 1.7623 || Test Loss: 1.6889
# Epoch 58 || batch 50 || Loss: 1.6966
# Epoch 58/1000 || Train Loss: 1.6984 || Test Loss: 1.6394
# Epoch 59 || batch 50 || Loss: 1.6374
# Epoch 59/1000 || Train Loss: 1.6437 || Test Loss: 1.5739
# Epoch 60 || batch 50 || Loss: 1.5935
# Epoch 60/1000 || Train Loss: 1.5851 || Test Loss: 1.5298
# Epoch 61 || batch 50 || Loss: 1.5282
# Epoch 61/1000 || Train Loss: 1.5259 || Test Loss: 1.4725
# Epoch 62 || batch 50 || Loss: 1.4879
# Epoch 62/1000 || Train Loss: 1.4747 || Test Loss: 1.4139
# Epoch 63 || batch 50 || Loss: 1.3995
# Epoch 63/1000 || Train Loss: 1.4294 || Test Loss: 1.3664
# Epoch 64 || batch 50 || Loss: 1.4067
# Epoch 64/1000 || Train Loss: 1.3712 || Test Loss: 1.3142
# Epoch 65 || batch 50 || Loss: 1.3085
# Epoch 65/1000 || Train Loss: 1.3233 || Test Loss: 1.2621
# Epoch 66 || batch 50 || Loss: 1.2784
# Epoch 66/1000 || Train Loss: 1.2680 || Test Loss: 1.2103
# Epoch 67 || batch 50 || Loss: 1.2319
# Epoch 67/1000 || Train Loss: 1.2181 || Test Loss: 1.1606
# Epoch 68 || batch 50 || Loss: 1.1735
# Epoch 68/1000 || Train Loss: 1.1741 || Test Loss: 1.1159
# Epoch 69 || batch 50 || Loss: 1.1131
# Epoch 69/1000 || Train Loss: 1.1307 || Test Loss: 1.0732
# Epoch 70 || batch 50 || Loss: 1.0835
# Epoch 70/1000 || Train Loss: 1.0820 || Test Loss: 1.0275
# Epoch 71 || batch 50 || Loss: 1.0317
# Epoch 71/1000 || Train Loss: 1.0378 || Test Loss: 0.9830
# Epoch 72 || batch 50 || Loss: 0.9718
# Epoch 72/1000 || Train Loss: 0.9922 || Test Loss: 0.9441
# Epoch 73 || batch 50 || Loss: 0.9471
# Epoch 73/1000 || Train Loss: 0.9469 || Test Loss: 0.9056
# Epoch 74 || batch 50 || Loss: 0.8989
# Epoch 74/1000 || Train Loss: 0.9130 || Test Loss: 0.8632
# Epoch 75 || batch 50 || Loss: 0.8624
# Epoch 75/1000 || Train Loss: 0.8678 || Test Loss: 0.8279
# Epoch 76 || batch 50 || Loss: 0.8332
# Epoch 76/1000 || Train Loss: 0.8333 || Test Loss: 0.7890
# Epoch 77 || batch 50 || Loss: 0.8015
# Epoch 77/1000 || Train Loss: 0.7951 || Test Loss: 0.7579
# Epoch 78 || batch 50 || Loss: 0.7692
# Epoch 78/1000 || Train Loss: 0.7623 || Test Loss: 0.7258
# Epoch 79 || batch 50 || Loss: 0.7297
# Epoch 79/1000 || Train Loss: 0.7285 || Test Loss: 0.6907
# Epoch 80 || batch 50 || Loss: 0.6924
# Epoch 80/1000 || Train Loss: 0.6968 || Test Loss: 0.6622
# Epoch 81 || batch 50 || Loss: 0.6713
# Epoch 81/1000 || Train Loss: 0.6667 || Test Loss: 0.6344
# Epoch 82 || batch 50 || Loss: 0.6404
# Epoch 82/1000 || Train Loss: 0.6385 || Test Loss: 0.6020
# Epoch 83 || batch 50 || Loss: 0.5969
# Epoch 83/1000 || Train Loss: 0.6146 || Test Loss: 0.5779
# Epoch 84 || batch 50 || Loss: 0.5854
# Epoch 84/1000 || Train Loss: 0.5821 || Test Loss: 0.5522
# Epoch 85 || batch 50 || Loss: 0.5592
# Epoch 85/1000 || Train Loss: 0.5549 || Test Loss: 0.5242
# Epoch 86 || batch 50 || Loss: 0.5283
# Epoch 86/1000 || Train Loss: 0.5302 || Test Loss: 0.5031
# Epoch 87 || batch 50 || Loss: 0.5146
# Epoch 87/1000 || Train Loss: 0.5061 || Test Loss: 0.4786
# Epoch 88 || batch 50 || Loss: 0.4798
# Epoch 88/1000 || Train Loss: 0.4831 || Test Loss: 0.4598
# Epoch 89 || batch 50 || Loss: 0.4622
# Epoch 89/1000 || Train Loss: 0.4619 || Test Loss: 0.4374
# Epoch 90 || batch 50 || Loss: 0.4452
# Epoch 90/1000 || Train Loss: 0.4421 || Test Loss: 0.4212
# Epoch 91 || batch 50 || Loss: 0.4178
# Epoch 91/1000 || Train Loss: 0.4229 || Test Loss: 0.4002
# Epoch 92 || batch 50 || Loss: 0.4129
# Epoch 92/1000 || Train Loss: 0.4039 || Test Loss: 0.3835
# Epoch 93 || batch 50 || Loss: 0.3902
# Epoch 93/1000 || Train Loss: 0.3865 || Test Loss: 0.3668
# Epoch 94 || batch 50 || Loss: 0.3721
# Epoch 94/1000 || Train Loss: 0.3693 || Test Loss: 0.3508
# Epoch 95 || batch 50 || Loss: 0.3544
# Epoch 95/1000 || Train Loss: 0.3549 || Test Loss: 0.3356
# Epoch 96 || batch 50 || Loss: 0.3391
# Epoch 96/1000 || Train Loss: 0.3392 || Test Loss: 0.3219
# Epoch 97 || batch 50 || Loss: 0.3258
# Epoch 97/1000 || Train Loss: 0.3257 || Test Loss: 0.3092
# Epoch 98 || batch 50 || Loss: 0.3092
# Epoch 98/1000 || Train Loss: 0.3121 || Test Loss: 0.2951
# Epoch 99 || batch 50 || Loss: 0.2961
# Epoch 99/1000 || Train Loss: 0.2991 || Test Loss: 0.2835
# Epoch 100 || batch 50 || Loss: 0.2905
# Epoch 100/1000 || Train Loss: 0.2873 || Test Loss: 0.2726
# Epoch 101 || batch 50 || Loss: 0.2756
# Epoch 101/1000 || Train Loss: 0.2757 || Test Loss: 0.2627
# Epoch 102 || batch 50 || Loss: 0.2664
# Epoch 102/1000 || Train Loss: 0.2643 || Test Loss: 0.2556
# Epoch 103 || batch 50 || Loss: 0.2552
# Epoch 103/1000 || Train Loss: 0.2549 || Test Loss: 0.2440
# Epoch 104 || batch 50 || Loss: 0.2442
# Epoch 104/1000 || Train Loss: 0.2451 || Test Loss: 0.2331
# Epoch 105 || batch 50 || Loss: 0.2323
# Epoch 105/1000 || Train Loss: 0.2354 || Test Loss: 0.2260
# Epoch 106 || batch 50 || Loss: 0.2306
# Epoch 106/1000 || Train Loss: 0.2269 || Test Loss: 0.2165
# Epoch 107 || batch 50 || Loss: 0.2181
# Epoch 107/1000 || Train Loss: 0.2204 || Test Loss: 0.2090
# Epoch 108 || batch 50 || Loss: 0.2116
# Epoch 108/1000 || Train Loss: 0.2132 || Test Loss: 0.2028
# Epoch 109 || batch 50 || Loss: 0.2029
# Epoch 109/1000 || Train Loss: 0.2048 || Test Loss: 0.1952
# Epoch 110 || batch 50 || Loss: 0.1992
# Epoch 110/1000 || Train Loss: 0.1972 || Test Loss: 0.1889
# Epoch 111 || batch 50 || Loss: 0.1865
# Epoch 111/1000 || Train Loss: 0.1908 || Test Loss: 0.1820
# Epoch 112 || batch 50 || Loss: 0.1869
# Epoch 112/1000 || Train Loss: 0.1844 || Test Loss: 0.1767
# Epoch 113 || batch 50 || Loss: 0.1771
# Epoch 113/1000 || Train Loss: 0.1788 || Test Loss: 0.1710
# Epoch 114 || batch 50 || Loss: 0.1745
# Epoch 114/1000 || Train Loss: 0.1721 || Test Loss: 0.1656
# Epoch 115 || batch 50 || Loss: 0.1694
# Epoch 115/1000 || Train Loss: 0.1674 || Test Loss: 0.1603
# Epoch 116 || batch 50 || Loss: 0.1589
# Epoch 116/1000 || Train Loss: 0.1624 || Test Loss: 0.1556
# Epoch 117 || batch 50 || Loss: 0.1553
# Epoch 117/1000 || Train Loss: 0.1602 || Test Loss: 0.1512
# Epoch 118 || batch 50 || Loss: 0.1542
# Epoch 118/1000 || Train Loss: 0.1525 || Test Loss: 0.1471
# Epoch 119 || batch 50 || Loss: 0.1464
# Epoch 119/1000 || Train Loss: 0.1492 || Test Loss: 0.1429
# Epoch 120 || batch 50 || Loss: 0.1425
# Epoch 120/1000 || Train Loss: 0.1449 || Test Loss: 0.1391
# Epoch 121 || batch 50 || Loss: 0.1413
# Epoch 121/1000 || Train Loss: 0.1402 || Test Loss: 0.1347
# Epoch 122 || batch 50 || Loss: 0.1387
# Epoch 122/1000 || Train Loss: 0.1367 || Test Loss: 0.1325
# Epoch 123 || batch 50 || Loss: 0.1319
# Epoch 123/1000 || Train Loss: 0.1328 || Test Loss: 0.1286
# Epoch 124 || batch 50 || Loss: 0.1280
# Epoch 124/1000 || Train Loss: 0.1300 || Test Loss: 0.1253
# Epoch 125 || batch 50 || Loss: 0.1260
# Epoch 125/1000 || Train Loss: 0.1264 || Test Loss: 0.1225
# Epoch 126 || batch 50 || Loss: 0.1234
# Epoch 126/1000 || Train Loss: 0.1229 || Test Loss: 0.1186
# Epoch 127 || batch 50 || Loss: 0.1198
# Epoch 127/1000 || Train Loss: 0.1200 || Test Loss: 0.1156
# Epoch 128 || batch 50 || Loss: 0.1165
# Epoch 128/1000 || Train Loss: 0.1175 || Test Loss: 0.1131
# Epoch 129 || batch 50 || Loss: 0.1113
# Epoch 129/1000 || Train Loss: 0.1148 || Test Loss: 0.1109
# Epoch 130 || batch 50 || Loss: 0.1122
# Epoch 130/1000 || Train Loss: 0.1113 || Test Loss: 0.1077
# Epoch 131 || batch 50 || Loss: 0.1055
# Epoch 131/1000 || Train Loss: 0.1096 || Test Loss: 0.1062
# Epoch 132 || batch 50 || Loss: 0.1060
# Epoch 132/1000 || Train Loss: 0.1070 || Test Loss: 0.1032
# Epoch 133 || batch 50 || Loss: 0.1049
# Epoch 133/1000 || Train Loss: 0.1042 || Test Loss: 0.1024
# Epoch 134 || batch 50 || Loss: 0.1036
# Epoch 134/1000 || Train Loss: 0.1018 || Test Loss: 0.0989
# Epoch 135 || batch 50 || Loss: 0.0992
# Epoch 135/1000 || Train Loss: 0.1005 || Test Loss: 0.0966
# Epoch 136 || batch 50 || Loss: 0.0976
# Epoch 136/1000 || Train Loss: 0.0977 || Test Loss: 0.0952
# Epoch 137 || batch 50 || Loss: 0.0936
# Epoch 137/1000 || Train Loss: 0.0959 || Test Loss: 0.0929
# Epoch 138 || batch 50 || Loss: 0.0937
# Epoch 138/1000 || Train Loss: 0.0938 || Test Loss: 0.0912
# Epoch 139 || batch 50 || Loss: 0.0915
# Epoch 139/1000 || Train Loss: 0.0922 || Test Loss: 0.0891
# Epoch 140 || batch 50 || Loss: 0.0896
# Epoch 140/1000 || Train Loss: 0.0908 || Test Loss: 0.0876
# Epoch 141 || batch 50 || Loss: 0.0888
# Epoch 141/1000 || Train Loss: 0.0886 || Test Loss: 0.0863
# Epoch 142 || batch 50 || Loss: 0.0876
# Epoch 142/1000 || Train Loss: 0.0872 || Test Loss: 0.0844
# Epoch 143 || batch 50 || Loss: 0.0853
# Epoch 143/1000 || Train Loss: 0.0855 || Test Loss: 0.0837
# Epoch 144 || batch 50 || Loss: 0.0839
# Epoch 144/1000 || Train Loss: 0.0838 || Test Loss: 0.0816
# Epoch 145 || batch 50 || Loss: 0.0819
# Epoch 145/1000 || Train Loss: 0.0822 || Test Loss: 0.0800
# Epoch 146 || batch 50 || Loss: 0.0786
# Epoch 146/1000 || Train Loss: 0.0805 || Test Loss: 0.0787
# Epoch 147 || batch 50 || Loss: 0.0774
# Epoch 147/1000 || Train Loss: 0.0801 || Test Loss: 0.0780
# Epoch 148 || batch 50 || Loss: 0.0771
# Epoch 148/1000 || Train Loss: 0.0782 || Test Loss: 0.0760
# Epoch 149 || batch 50 || Loss: 0.0772
# Epoch 149/1000 || Train Loss: 0.0766 || Test Loss: 0.0748
# Epoch 150 || batch 50 || Loss: 0.0753
# Epoch 150/1000 || Train Loss: 0.0755 || Test Loss: 0.0734
# Epoch 151 || batch 50 || Loss: 0.0748
# Epoch 151/1000 || Train Loss: 0.0739 || Test Loss: 0.0723
# Epoch 152 || batch 50 || Loss: 0.0711
# Epoch 152/1000 || Train Loss: 0.0743 || Test Loss: 0.0713
# Epoch 153 || batch 50 || Loss: 0.0725
# Epoch 153/1000 || Train Loss: 0.0718 || Test Loss: 0.0700
# Epoch 154 || batch 50 || Loss: 0.0712
# Epoch 154/1000 || Train Loss: 0.0708 || Test Loss: 0.0690
# Epoch 155 || batch 50 || Loss: 0.0683
# Epoch 155/1000 || Train Loss: 0.0695 || Test Loss: 0.0680
# Epoch 156 || batch 50 || Loss: 0.0689
# Epoch 156/1000 || Train Loss: 0.0684 || Test Loss: 0.0668
# Epoch 157 || batch 50 || Loss: 0.0674
# Epoch 157/1000 || Train Loss: 0.0676 || Test Loss: 0.0660
# Epoch 158 || batch 50 || Loss: 0.0670
# Epoch 158/1000 || Train Loss: 0.0665 || Test Loss: 0.0649
# Epoch 159 || batch 50 || Loss: 0.0651
# Epoch 159/1000 || Train Loss: 0.0655 || Test Loss: 0.0640
# Epoch 160 || batch 50 || Loss: 0.0651
# Epoch 160/1000 || Train Loss: 0.0645 || Test Loss: 0.0636
# Epoch 161 || batch 50 || Loss: 0.0631
# Epoch 161/1000 || Train Loss: 0.0636 || Test Loss: 0.0623
# Epoch 162 || batch 50 || Loss: 0.0634
# Epoch 162/1000 || Train Loss: 0.0626 || Test Loss: 0.0611
# Epoch 163 || batch 50 || Loss: 0.0623
# Epoch 163/1000 || Train Loss: 0.0619 || Test Loss: 0.0603
# Epoch 164 || batch 50 || Loss: 0.0602
# Epoch 164/1000 || Train Loss: 0.0619 || Test Loss: 0.0596
# Epoch 165 || batch 50 || Loss: 0.0597
# Epoch 165/1000 || Train Loss: 0.0603 || Test Loss: 0.0588
# Epoch 166 || batch 50 || Loss: 0.0591
# Epoch 166/1000 || Train Loss: 0.0595 || Test Loss: 0.0579
# Epoch 167 || batch 50 || Loss: 0.0580
# Epoch 167/1000 || Train Loss: 0.0585 || Test Loss: 0.0573
# Epoch 168 || batch 50 || Loss: 0.0581
# Epoch 168/1000 || Train Loss: 0.0580 || Test Loss: 0.0564
# Epoch 169 || batch 50 || Loss: 0.0572
# Epoch 169/1000 || Train Loss: 0.0572 || Test Loss: 0.0558
# Epoch 170 || batch 50 || Loss: 0.0571
# Epoch 170/1000 || Train Loss: 0.0563 || Test Loss: 0.0551
# Epoch 171 || batch 50 || Loss: 0.0548
# Epoch 171/1000 || Train Loss: 0.0557 || Test Loss: 0.0544
# Epoch 172 || batch 50 || Loss: 0.0545
# Epoch 172/1000 || Train Loss: 0.0551 || Test Loss: 0.0538
# Epoch 173 || batch 50 || Loss: 0.0532
# Epoch 173/1000 || Train Loss: 0.0544 || Test Loss: 0.0529
# Epoch 174 || batch 50 || Loss: 0.0537
# Epoch 174/1000 || Train Loss: 0.0538 || Test Loss: 0.0524
# Epoch 175 || batch 50 || Loss: 0.0532
# Epoch 175/1000 || Train Loss: 0.0531 || Test Loss: 0.0517
# Epoch 176 || batch 50 || Loss: 0.0527
# Epoch 176/1000 || Train Loss: 0.0524 || Test Loss: 0.0512
# Epoch 177 || batch 50 || Loss: 0.0523
# Epoch 177/1000 || Train Loss: 0.0518 || Test Loss: 0.0507
# Epoch 178 || batch 50 || Loss: 0.0516
# Epoch 178/1000 || Train Loss: 0.0511 || Test Loss: 0.0501
# Epoch 179 || batch 50 || Loss: 0.0512
# Epoch 179/1000 || Train Loss: 0.0506 || Test Loss: 0.0495
# Epoch 180 || batch 50 || Loss: 0.0504
# Epoch 180/1000 || Train Loss: 0.0499 || Test Loss: 0.0490
# Epoch 181 || batch 50 || Loss: 0.0497
# Epoch 181/1000 || Train Loss: 0.0495 || Test Loss: 0.0483
# Epoch 182 || batch 50 || Loss: 0.0486
# Epoch 182/1000 || Train Loss: 0.0489 || Test Loss: 0.0479
# Epoch 183 || batch 50 || Loss: 0.0491
# Epoch 183/1000 || Train Loss: 0.0484 || Test Loss: 0.0474
# Epoch 184 || batch 50 || Loss: 0.0474
# Epoch 184/1000 || Train Loss: 0.0478 || Test Loss: 0.0468
# Epoch 185 || batch 50 || Loss: 0.0480
# Epoch 185/1000 || Train Loss: 0.0474 || Test Loss: 0.0464
# Epoch 186 || batch 50 || Loss: 0.0469
# Epoch 186/1000 || Train Loss: 0.0471 || Test Loss: 0.0459
# Epoch 187 || batch 50 || Loss: 0.0471
# Epoch 187/1000 || Train Loss: 0.0464 || Test Loss: 0.0453
# Epoch 188 || batch 50 || Loss: 0.0449
# Epoch 188/1000 || Train Loss: 0.0459 || Test Loss: 0.0450
# Epoch 189 || batch 50 || Loss: 0.0459
# Epoch 189/1000 || Train Loss: 0.0454 || Test Loss: 0.0445
# Epoch 190 || batch 50 || Loss: 0.0452
# Epoch 190/1000 || Train Loss: 0.0449 || Test Loss: 0.0440
# Epoch 191 || batch 50 || Loss: 0.0444
# Epoch 191/1000 || Train Loss: 0.0445 || Test Loss: 0.0435
# Epoch 192 || batch 50 || Loss: 0.0433
# Epoch 192/1000 || Train Loss: 0.0440 || Test Loss: 0.0431
# Epoch 193 || batch 50 || Loss: 0.0438
# Epoch 193/1000 || Train Loss: 0.0437 || Test Loss: 0.0428
# Epoch 194 || batch 50 || Loss: 0.0437
# Epoch 194/1000 || Train Loss: 0.0433 || Test Loss: 0.0422
# Epoch 195 || batch 50 || Loss: 0.0414
# Epoch 195/1000 || Train Loss: 0.0428 || Test Loss: 0.0421
# Epoch 196 || batch 50 || Loss: 0.0427
# Epoch 196/1000 || Train Loss: 0.0424 || Test Loss: 0.0416
# Epoch 197 || batch 50 || Loss: 0.0422
# Epoch 197/1000 || Train Loss: 0.0421 || Test Loss: 0.0411
# Epoch 198 || batch 50 || Loss: 0.0408
# Epoch 198/1000 || Train Loss: 0.0417 || Test Loss: 0.0408
# Epoch 199 || batch 50 || Loss: 0.0412
# Epoch 199/1000 || Train Loss: 0.0411 || Test Loss: 0.0404
# Epoch 200 || batch 50 || Loss: 0.0405
# Epoch 200/1000 || Train Loss: 0.0417 || Test Loss: 0.0400
# Epoch 201 || batch 50 || Loss: 0.0408
# Epoch 201/1000 || Train Loss: 0.0405 || Test Loss: 0.0397
# Epoch 202 || batch 50 || Loss: 0.0388
# Epoch 202/1000 || Train Loss: 0.0410 || Test Loss: 0.0395
# Epoch 203 || batch 50 || Loss: 0.0390
# Epoch 203/1000 || Train Loss: 0.0399 || Test Loss: 0.0391
# Epoch 204 || batch 50 || Loss: 0.0395
# Epoch 204/1000 || Train Loss: 0.0395 || Test Loss: 0.0386
# Epoch 205 || batch 50 || Loss: 0.0392
# Epoch 205/1000 || Train Loss: 0.0392 || Test Loss: 0.0382
# Epoch 206 || batch 50 || Loss: 0.0390
# Epoch 206/1000 || Train Loss: 0.0388 || Test Loss: 0.0379
# Epoch 207 || batch 50 || Loss: 0.0388
# Epoch 207/1000 || Train Loss: 0.0384 || Test Loss: 0.0376
# Epoch 208 || batch 50 || Loss: 0.0376
# Epoch 208/1000 || Train Loss: 0.0382 || Test Loss: 0.0379
# Epoch 209 || batch 50 || Loss: 0.0378
# Epoch 209/1000 || Train Loss: 0.0378 || Test Loss: 0.0370
# Epoch 210 || batch 50 || Loss: 0.0379
# Epoch 210/1000 || Train Loss: 0.0375 || Test Loss: 0.0366
# Epoch 211 || batch 50 || Loss: 0.0364
# Epoch 211/1000 || Train Loss: 0.0370 || Test Loss: 0.0370
# Epoch 212 || batch 50 || Loss: 0.0364
# Epoch 212/1000 || Train Loss: 0.0368 || Test Loss: 0.0361
# Epoch 213 || batch 50 || Loss: 0.0370
# Epoch 213/1000 || Train Loss: 0.0366 || Test Loss: 0.0358
# Epoch 214 || batch 50 || Loss: 0.0368
# Epoch 214/1000 || Train Loss: 0.0363 || Test Loss: 0.0355
# Epoch 215 || batch 50 || Loss: 0.0354
# Epoch 215/1000 || Train Loss: 0.0360 || Test Loss: 0.0352
# Epoch 216 || batch 50 || Loss: 0.0352
# Epoch 216/1000 || Train Loss: 0.0357 || Test Loss: 0.0350
# Epoch 217 || batch 50 || Loss: 0.0357
# Epoch 217/1000 || Train Loss: 0.0354 || Test Loss: 0.0347
# Epoch 218 || batch 50 || Loss: 0.0341
# Epoch 218/1000 || Train Loss: 0.0353 || Test Loss: 0.0350
# Epoch 219 || batch 50 || Loss: 0.0353
# Epoch 219/1000 || Train Loss: 0.0350 || Test Loss: 0.0341
# Epoch 220 || batch 50 || Loss: 0.0340
# Epoch 220/1000 || Train Loss: 0.0346 || Test Loss: 0.0340
# Epoch 221 || batch 50 || Loss: 0.0346
# Epoch 221/1000 || Train Loss: 0.0344 || Test Loss: 0.0336
# Epoch 222 || batch 50 || Loss: 0.0344
# Epoch 222/1000 || Train Loss: 0.0341 || Test Loss: 0.0334
# Epoch 223 || batch 50 || Loss: 0.0342
# Epoch 223/1000 || Train Loss: 0.0339 || Test Loss: 0.0332
# Epoch 224 || batch 50 || Loss: 0.0341
# Epoch 224/1000 || Train Loss: 0.0337 || Test Loss: 0.0329
# Epoch 225 || batch 50 || Loss: 0.0316
# Epoch 225/1000 || Train Loss: 0.0334 || Test Loss: 0.0326
# Epoch 226 || batch 50 || Loss: 0.0334
# Epoch 226/1000 || Train Loss: 0.0331 || Test Loss: 0.0324
# Epoch 227 || batch 50 || Loss: 0.0330
# Epoch 227/1000 || Train Loss: 0.0329 || Test Loss: 0.0322
# Epoch 228 || batch 50 || Loss: 0.0331
# Epoch 228/1000 || Train Loss: 0.0326 || Test Loss: 0.0320
# Epoch 229 || batch 50 || Loss: 0.0329
# Epoch 229/1000 || Train Loss: 0.0324 || Test Loss: 0.0317
# Epoch 230 || batch 50 || Loss: 0.0316
# Epoch 230/1000 || Train Loss: 0.0322 || Test Loss: 0.0314
# Epoch 231 || batch 50 || Loss: 0.0320
# Epoch 231/1000 || Train Loss: 0.0319 || Test Loss: 0.0313
# Epoch 232 || batch 50 || Loss: 0.0321
# Epoch 232/1000 || Train Loss: 0.0317 || Test Loss: 0.0312
# Epoch 233 || batch 50 || Loss: 0.0320
# Epoch 233/1000 || Train Loss: 0.0316 || Test Loss: 0.0309
# Epoch 234 || batch 50 || Loss: 0.0318
# Epoch 234/1000 || Train Loss: 0.0314 || Test Loss: 0.0305
# Epoch 235 || batch 50 || Loss: 0.0313
# Epoch 235/1000 || Train Loss: 0.0311 || Test Loss: 0.0304
# Epoch 236 || batch 50 || Loss: 0.0314
# Epoch 236/1000 || Train Loss: 0.0308 || Test Loss: 0.0302
# Epoch 237 || batch 50 || Loss: 0.0301
# Epoch 237/1000 || Train Loss: 0.0307 || Test Loss: 0.0300
# Epoch 238 || batch 50 || Loss: 0.0309
# Epoch 238/1000 || Train Loss: 0.0305 || Test Loss: 0.0298
# Epoch 239 || batch 50 || Loss: 0.0306
# Epoch 239/1000 || Train Loss: 0.0303 || Test Loss: 0.0298
# Epoch 240 || batch 50 || Loss: 0.0305
# Epoch 240/1000 || Train Loss: 0.0301 || Test Loss: 0.0294
# Epoch 241 || batch 50 || Loss: 0.0302
# Epoch 241/1000 || Train Loss: 0.0300 || Test Loss: 0.0293
# Epoch 242 || batch 50 || Loss: 0.0291
# Epoch 242/1000 || Train Loss: 0.0297 || Test Loss: 0.0291
# Epoch 243 || batch 50 || Loss: 0.0289
# Epoch 243/1000 || Train Loss: 0.0296 || Test Loss: 0.0288
# Epoch 244 || batch 50 || Loss: 0.0297
# Epoch 244/1000 || Train Loss: 0.0294 || Test Loss: 0.0287
# Epoch 245 || batch 50 || Loss: 0.0295
# Epoch 245/1000 || Train Loss: 0.0292 || Test Loss: 0.0286
# Epoch 246 || batch 50 || Loss: 0.0292
# Epoch 246/1000 || Train Loss: 0.0290 || Test Loss: 0.0283
# Epoch 247 || batch 50 || Loss: 0.0285
# Epoch 247/1000 || Train Loss: 0.0295 || Test Loss: 0.0283
# Epoch 248 || batch 50 || Loss: 0.0287
# Epoch 248/1000 || Train Loss: 0.0285 || Test Loss: 0.0280
# Epoch 249 || batch 50 || Loss: 0.0289
# Epoch 249/1000 || Train Loss: 0.0284 || Test Loss: 0.0278
# Epoch 250 || batch 50 || Loss: 0.0288
# Epoch 250/1000 || Train Loss: 0.0282 || Test Loss: 0.0276
# Epoch 251 || batch 50 || Loss: 0.0283
# Epoch 251/1000 || Train Loss: 0.0282 || Test Loss: 0.0275
# Epoch 252 || batch 50 || Loss: 0.0285
# Epoch 252/1000 || Train Loss: 0.0279 || Test Loss: 0.0274
# Epoch 253 || batch 50 || Loss: 0.0271
# Epoch 253/1000 || Train Loss: 0.0278 || Test Loss: 0.0272
# Epoch 254 || batch 50 || Loss: 0.0280
# Epoch 254/1000 || Train Loss: 0.0276 || Test Loss: 0.0270
# Epoch 255 || batch 50 || Loss: 0.0258
# Epoch 255/1000 || Train Loss: 0.0280 || Test Loss: 0.0270
# Epoch 256 || batch 50 || Loss: 0.0275
# Epoch 256/1000 || Train Loss: 0.0274 || Test Loss: 0.0267
# Epoch 257 || batch 50 || Loss: 0.0274
# Epoch 257/1000 || Train Loss: 0.0272 || Test Loss: 0.0266
# Epoch 258 || batch 50 || Loss: 0.0262
# Epoch 258/1000 || Train Loss: 0.0270 || Test Loss: 0.0264
# Epoch 259 || batch 50 || Loss: 0.0252
# Epoch 259/1000 || Train Loss: 0.0269 || Test Loss: 0.0262
# Epoch 260 || batch 50 || Loss: 0.0270
# Epoch 260/1000 || Train Loss: 0.0267 || Test Loss: 0.0261
# Epoch 261 || batch 50 || Loss: 0.0260
# Epoch 261/1000 || Train Loss: 0.0265 || Test Loss: 0.0259
# Epoch 262 || batch 50 || Loss: 0.0269
# Epoch 262/1000 || Train Loss: 0.0263 || Test Loss: 0.0257
# Epoch 263 || batch 50 || Loss: 0.0267
# Epoch 263/1000 || Train Loss: 0.0262 || Test Loss: 0.0257
# Epoch 264 || batch 50 || Loss: 0.0265
# Epoch 264/1000 || Train Loss: 0.0261 || Test Loss: 0.0255
# Epoch 265 || batch 50 || Loss: 0.0262
# Epoch 265/1000 || Train Loss: 0.0260 || Test Loss: 0.0254
# Epoch 266 || batch 50 || Loss: 0.0252
# Epoch 266/1000 || Train Loss: 0.0258 || Test Loss: 0.0251
# Epoch 267 || batch 50 || Loss: 0.0251
# Epoch 267/1000 || Train Loss: 0.0257 || Test Loss: 0.0250
# Epoch 268 || batch 50 || Loss: 0.0260
# Epoch 268/1000 || Train Loss: 0.0255 || Test Loss: 0.0250
# Epoch 269 || batch 50 || Loss: 0.0240
# Epoch 269/1000 || Train Loss: 0.0253 || Test Loss: 0.0248
# Epoch 270 || batch 50 || Loss: 0.0254
# Epoch 270/1000 || Train Loss: 0.0252 || Test Loss: 0.0247
# Epoch 271 || batch 50 || Loss: 0.0256
# Epoch 271/1000 || Train Loss: 0.0251 || Test Loss: 0.0245
# Epoch 272 || batch 50 || Loss: 0.0252
# Epoch 272/1000 || Train Loss: 0.0250 || Test Loss: 0.0244
# Epoch 273 || batch 50 || Loss: 0.0234
# Epoch 273/1000 || Train Loss: 0.0249 || Test Loss: 0.0243
# Epoch 274 || batch 50 || Loss: 0.0252
# Epoch 274/1000 || Train Loss: 0.0247 || Test Loss: 0.0241
# Epoch 275 || batch 50 || Loss: 0.0250
# Epoch 275/1000 || Train Loss: 0.0246 || Test Loss: 0.0240
# Epoch 276 || batch 50 || Loss: 0.0247
# Epoch 276/1000 || Train Loss: 0.0245 || Test Loss: 0.0239
# Epoch 277 || batch 50 || Loss: 0.0230
# Epoch 277/1000 || Train Loss: 0.0252 || Test Loss: 0.0238
# Epoch 278 || batch 50 || Loss: 0.0237
# Epoch 278/1000 || Train Loss: 0.0243 || Test Loss: 0.0237
# Epoch 279 || batch 50 || Loss: 0.0229
# Epoch 279/1000 || Train Loss: 0.0242 || Test Loss: 0.0235
# Epoch 280 || batch 50 || Loss: 0.0235
# Epoch 280/1000 || Train Loss: 0.0240 || Test Loss: 0.0235
# Epoch 281 || batch 50 || Loss: 0.0242
# Epoch 281/1000 || Train Loss: 0.0239 || Test Loss: 0.0232
# Epoch 282 || batch 50 || Loss: 0.0241
# Epoch 282/1000 || Train Loss: 0.0237 || Test Loss: 0.0238
# Epoch 283 || batch 50 || Loss: 0.0240
# Epoch 283/1000 || Train Loss: 0.0236 || Test Loss: 0.0230
# Epoch 284 || batch 50 || Loss: 0.0237
# Epoch 284/1000 || Train Loss: 0.0235 || Test Loss: 0.0229
# Epoch 285 || batch 50 || Loss: 0.0227
# Epoch 285/1000 || Train Loss: 0.0242 || Test Loss: 0.0229
# Epoch 286 || batch 50 || Loss: 0.0236
# Epoch 286/1000 || Train Loss: 0.0233 || Test Loss: 0.0228
# Epoch 287 || batch 50 || Loss: 0.0232
# Epoch 287/1000 || Train Loss: 0.0229 || Test Loss: 0.0226
# Epoch 288 || batch 50 || Loss: 0.0235
# Epoch 288/1000 || Train Loss: 0.0231 || Test Loss: 0.0225
# Epoch 289 || batch 50 || Loss: 0.0232
# Epoch 289/1000 || Train Loss: 0.0229 || Test Loss: 0.0224
# Epoch 290 || batch 50 || Loss: 0.0221
# Epoch 290/1000 || Train Loss: 0.0228 || Test Loss: 0.0223
# Epoch 291 || batch 50 || Loss: 0.0230
# Epoch 291/1000 || Train Loss: 0.0228 || Test Loss: 0.0221
# Epoch 292 || batch 50 || Loss: 0.0219
# Epoch 292/1000 || Train Loss: 0.0226 || Test Loss: 0.0221
# Epoch 293 || batch 50 || Loss: 0.0228
# Epoch 293/1000 || Train Loss: 0.0225 || Test Loss: 0.0220
# Epoch 294 || batch 50 || Loss: 0.0228
# Epoch 294/1000 || Train Loss: 0.0224 || Test Loss: 0.0219
# Epoch 295 || batch 50 || Loss: 0.0217
# Epoch 295/1000 || Train Loss: 0.0223 || Test Loss: 0.0218
# Epoch 296 || batch 50 || Loss: 0.0216
# Epoch 296/1000 || Train Loss: 0.0222 || Test Loss: 0.0217
# Epoch 297 || batch 50 || Loss: 0.0226
# Epoch 297/1000 || Train Loss: 0.0221 || Test Loss: 0.0223
# Epoch 298 || batch 50 || Loss: 0.0222
# Epoch 298/1000 || Train Loss: 0.0220 || Test Loss: 0.0215
# Epoch 299 || batch 50 || Loss: 0.0214
# Epoch 299/1000 || Train Loss: 0.0219 || Test Loss: 0.0214
# Epoch 300 || batch 50 || Loss: 0.0221
# Epoch 300/1000 || Train Loss: 0.0218 || Test Loss: 0.0214
# Epoch 301 || batch 50 || Loss: 0.0211
# Epoch 301/1000 || Train Loss: 0.0217 || Test Loss: 0.0211
# Epoch 302 || batch 50 || Loss: 0.0220
# Epoch 302/1000 || Train Loss: 0.0217 || Test Loss: 0.0211
# Epoch 303 || batch 50 || Loss: 0.0219
# Epoch 303/1000 || Train Loss: 0.0215 || Test Loss: 0.0210
# Epoch 304 || batch 50 || Loss: 0.0216
# Epoch 304/1000 || Train Loss: 0.0214 || Test Loss: 0.0209
# Epoch 305 || batch 50 || Loss: 0.0206
# Epoch 305/1000 || Train Loss: 0.0214 || Test Loss: 0.0208
# Epoch 306 || batch 50 || Loss: 0.0215
# Epoch 306/1000 || Train Loss: 0.0212 || Test Loss: 0.0207
# Epoch 307 || batch 50 || Loss: 0.0214
# Epoch 307/1000 || Train Loss: 0.0212 || Test Loss: 0.0207
# Epoch 308 || batch 50 || Loss: 0.0216
# Epoch 308/1000 || Train Loss: 0.0211 || Test Loss: 0.0206
# Epoch 309 || batch 50 || Loss: 0.0201
# Epoch 309/1000 || Train Loss: 0.0219 || Test Loss: 0.0205
# Epoch 310 || batch 50 || Loss: 0.0205
# Epoch 310/1000 || Train Loss: 0.0209 || Test Loss: 0.0204
# Epoch 311 || batch 50 || Loss: 0.0204
# Epoch 311/1000 || Train Loss: 0.0208 || Test Loss: 0.0203
# Epoch 312 || batch 50 || Loss: 0.0202
# Epoch 312/1000 || Train Loss: 0.0207 || Test Loss: 0.0202
# Epoch 313 || batch 50 || Loss: 0.0208
# Epoch 313/1000 || Train Loss: 0.0206 || Test Loss: 0.0208
# Epoch 314 || batch 50 || Loss: 0.0199
# Epoch 314/1000 || Train Loss: 0.0206 || Test Loss: 0.0200
# Epoch 315 || batch 50 || Loss: 0.0207
# Epoch 315/1000 || Train Loss: 0.0206 || Test Loss: 0.0199
# Epoch 316 || batch 50 || Loss: 0.0195
# Epoch 316/1000 || Train Loss: 0.0204 || Test Loss: 0.0199
# Epoch 317 || batch 50 || Loss: 0.0204
# Epoch 317/1000 || Train Loss: 0.0203 || Test Loss: 0.0198
# Epoch 318 || batch 50 || Loss: 0.0187
# Epoch 318/1000 || Train Loss: 0.0202 || Test Loss: 0.0197
# Epoch 319 || batch 50 || Loss: 0.0206
# Epoch 319/1000 || Train Loss: 0.0201 || Test Loss: 0.0196
# Epoch 320 || batch 50 || Loss: 0.0204
# Epoch 320/1000 || Train Loss: 0.0200 || Test Loss: 0.0195
# Epoch 321 || batch 50 || Loss: 0.0200
# Epoch 321/1000 || Train Loss: 0.0201 || Test Loss: 0.0195
# Epoch 322 || batch 50 || Loss: 0.0201
# Epoch 322/1000 || Train Loss: 0.0199 || Test Loss: 0.0194
# Epoch 323 || batch 50 || Loss: 0.0201
# Epoch 323/1000 || Train Loss: 0.0198 || Test Loss: 0.0193
# Epoch 324 || batch 50 || Loss: 0.0201
# Epoch 324/1000 || Train Loss: 0.0197 || Test Loss: 0.0192
# Epoch 325 || batch 50 || Loss: 0.0200
# Epoch 325/1000 || Train Loss: 0.0197 || Test Loss: 0.0191
# Epoch 326 || batch 50 || Loss: 0.0199
# Epoch 326/1000 || Train Loss: 0.0196 || Test Loss: 0.0190
# Epoch 327 || batch 50 || Loss: 0.0198
# Epoch 327/1000 || Train Loss: 0.0195 || Test Loss: 0.0190
# Epoch 328 || batch 50 || Loss: 0.0197
# Epoch 328/1000 || Train Loss: 0.0194 || Test Loss: 0.0189
# Epoch 329 || batch 50 || Loss: 0.0195
# Epoch 329/1000 || Train Loss: 0.0194 || Test Loss: 0.0188
# Epoch 330 || batch 50 || Loss: 0.0196
# Epoch 330/1000 || Train Loss: 0.0192 || Test Loss: 0.0188
# Epoch 331 || batch 50 || Loss: 0.0185
# Epoch 331/1000 || Train Loss: 0.0193 || Test Loss: 0.0187
# Epoch 332 || batch 50 || Loss: 0.0195
# Epoch 332/1000 || Train Loss: 0.0191 || Test Loss: 0.0187
# Epoch 333 || batch 50 || Loss: 0.0186
# Epoch 333/1000 || Train Loss: 0.0191 || Test Loss: 0.0185
# Epoch 334 || batch 50 || Loss: 0.0192
# Epoch 334/1000 || Train Loss: 0.0190 || Test Loss: 0.0185
# Epoch 335 || batch 50 || Loss: 0.0193
# Epoch 335/1000 || Train Loss: 0.0189 || Test Loss: 0.0184
# Epoch 336 || batch 50 || Loss: 0.0192
# Epoch 336/1000 || Train Loss: 0.0188 || Test Loss: 0.0183
# Epoch 337 || batch 50 || Loss: 0.0192
# Epoch 337/1000 || Train Loss: 0.0187 || Test Loss: 0.0183
# Epoch 338 || batch 50 || Loss: 0.0190
# Epoch 338/1000 || Train Loss: 0.0187 || Test Loss: 0.0182
# Epoch 339 || batch 50 || Loss: 0.0190
# Epoch 339/1000 || Train Loss: 0.0186 || Test Loss: 0.0182
# Epoch 340 || batch 50 || Loss: 0.0180
# Epoch 340/1000 || Train Loss: 0.0185 || Test Loss: 0.0181
# Epoch 341 || batch 50 || Loss: 0.0179
# Epoch 341/1000 || Train Loss: 0.0185 || Test Loss: 0.0180
# Epoch 342 || batch 50 || Loss: 0.0187
# Epoch 342/1000 || Train Loss: 0.0185 || Test Loss: 0.0179
# Epoch 343 || batch 50 || Loss: 0.0179
# Epoch 343/1000 || Train Loss: 0.0184 || Test Loss: 0.0179
# Epoch 344 || batch 50 || Loss: 0.0186
# Epoch 344/1000 || Train Loss: 0.0183 || Test Loss: 0.0178
# Epoch 345 || batch 50 || Loss: 0.0177
# Epoch 345/1000 || Train Loss: 0.0182 || Test Loss: 0.0177
# Epoch 346 || batch 50 || Loss: 0.0184
# Epoch 346/1000 || Train Loss: 0.0182 || Test Loss: 0.0177
# Epoch 347 || batch 50 || Loss: 0.0185
# Epoch 347/1000 || Train Loss: 0.0181 || Test Loss: 0.0176
# Epoch 348 || batch 50 || Loss: 0.0183
# Epoch 348/1000 || Train Loss: 0.0180 || Test Loss: 0.0176
# Epoch 349 || batch 50 || Loss: 0.0173
# Epoch 349/1000 || Train Loss: 0.0180 || Test Loss: 0.0175
# Epoch 350 || batch 50 || Loss: 0.0174
# Epoch 350/1000 || Train Loss: 0.0179 || Test Loss: 0.0174
# Epoch 351 || batch 50 || Loss: 0.0182
# Epoch 351/1000 || Train Loss: 0.0179 || Test Loss: 0.0174
# Epoch 352 || batch 50 || Loss: 0.0171
# Epoch 352/1000 || Train Loss: 0.0178 || Test Loss: 0.0173
# Epoch 353 || batch 50 || Loss: 0.0171
# Epoch 353/1000 || Train Loss: 0.0178 || Test Loss: 0.0172
# Epoch 354 || batch 50 || Loss: 0.0179
# Epoch 354/1000 || Train Loss: 0.0176 || Test Loss: 0.0172
# Epoch 355 || batch 50 || Loss: 0.0179
# Epoch 355/1000 || Train Loss: 0.0176 || Test Loss: 0.0171
# Epoch 356 || batch 50 || Loss: 0.0168
# Epoch 356/1000 || Train Loss: 0.0184 || Test Loss: 0.0171
# Epoch 357 || batch 50 || Loss: 0.0178
# Epoch 357/1000 || Train Loss: 0.0175 || Test Loss: 0.0170
# Epoch 358 || batch 50 || Loss: 0.0177
# Epoch 358/1000 || Train Loss: 0.0174 || Test Loss: 0.0169
# Epoch 359 || batch 50 || Loss: 0.0176
# Epoch 359/1000 || Train Loss: 0.0174 || Test Loss: 0.0169
# Epoch 360 || batch 50 || Loss: 0.0166
# Epoch 360/1000 || Train Loss: 0.0182 || Test Loss: 0.0179
# Epoch 361 || batch 50 || Loss: 0.0176
# Epoch 361/1000 || Train Loss: 0.0174 || Test Loss: 0.0168
# Epoch 362 || batch 50 || Loss: 0.0175
# Epoch 362/1000 || Train Loss: 0.0173 || Test Loss: 0.0167
# Epoch 363 || batch 50 || Loss: 0.0173
# Epoch 363/1000 || Train Loss: 0.0172 || Test Loss: 0.0167
# Epoch 364 || batch 50 || Loss: 0.0171
# Epoch 364/1000 || Train Loss: 0.0170 || Test Loss: 0.0166
# Epoch 365 || batch 50 || Loss: 0.0165
# Epoch 365/1000 || Train Loss: 0.0170 || Test Loss: 0.0165
# Epoch 366 || batch 50 || Loss: 0.0174
# Epoch 366/1000 || Train Loss: 0.0170 || Test Loss: 0.0165
# Epoch 367 || batch 50 || Loss: 0.0171
# Epoch 367/1000 || Train Loss: 0.0169 || Test Loss: 0.0164
# Epoch 368 || batch 50 || Loss: 0.0172
# Epoch 368/1000 || Train Loss: 0.0169 || Test Loss: 0.0164
# Epoch 369 || batch 50 || Loss: 0.0172
# Epoch 369/1000 || Train Loss: 0.0168 || Test Loss: 0.0163
# Epoch 370 || batch 50 || Loss: 0.0170
# Epoch 370/1000 || Train Loss: 0.0169 || Test Loss: 0.0163
# Epoch 371 || batch 50 || Loss: 0.0169
# Epoch 371/1000 || Train Loss: 0.0167 || Test Loss: 0.0162
# Epoch 372 || batch 50 || Loss: 0.0161
# Epoch 372/1000 || Train Loss: 0.0167 || Test Loss: 0.0161
# Epoch 373 || batch 50 || Loss: 0.0170
# Epoch 373/1000 || Train Loss: 0.0166 || Test Loss: 0.0161
# Epoch 374 || batch 50 || Loss: 0.0166
# Epoch 374/1000 || Train Loss: 0.0164 || Test Loss: 0.0160
# Epoch 375 || batch 50 || Loss: 0.0167
# Epoch 375/1000 || Train Loss: 0.0165 || Test Loss: 0.0160
# Epoch 376 || batch 50 || Loss: 0.0167
# Epoch 376/1000 || Train Loss: 0.0165 || Test Loss: 0.0160
# Epoch 377 || batch 50 || Loss: 0.0166
# Epoch 377/1000 || Train Loss: 0.0164 || Test Loss: 0.0159
# Epoch 378 || batch 50 || Loss: 0.0168
# Epoch 378/1000 || Train Loss: 0.0163 || Test Loss: 0.0159
# Epoch 379 || batch 50 || Loss: 0.0166
# Epoch 379/1000 || Train Loss: 0.0163 || Test Loss: 0.0158
# Epoch 380 || batch 50 || Loss: 0.0165
# Epoch 380/1000 || Train Loss: 0.0163 || Test Loss: 0.0158
# Epoch 381 || batch 50 || Loss: 0.0156
# Epoch 381/1000 || Train Loss: 0.0170 || Test Loss: 0.0158
# Epoch 382 || batch 50 || Loss: 0.0165
# Epoch 382/1000 || Train Loss: 0.0162 || Test Loss: 0.0157
# Epoch 383 || batch 50 || Loss: 0.0164
# Epoch 383/1000 || Train Loss: 0.0161 || Test Loss: 0.0156
# Epoch 384 || batch 50 || Loss: 0.0164
# Epoch 384/1000 || Train Loss: 0.0161 || Test Loss: 0.0155
# Epoch 385 || batch 50 || Loss: 0.0153
# Epoch 385/1000 || Train Loss: 0.0160 || Test Loss: 0.0155
# Epoch 386 || batch 50 || Loss: 0.0154
# Epoch 386/1000 || Train Loss: 0.0160 || Test Loss: 0.0154
# Epoch 387 || batch 50 || Loss: 0.0162
# Epoch 387/1000 || Train Loss: 0.0159 || Test Loss: 0.0154
# Epoch 388 || batch 50 || Loss: 0.0163
# Epoch 388/1000 || Train Loss: 0.0158 || Test Loss: 0.0154
# Epoch 389 || batch 50 || Loss: 0.0153
# Epoch 389/1000 || Train Loss: 0.0158 || Test Loss: 0.0153
# Epoch 390 || batch 50 || Loss: 0.0160
# Epoch 390/1000 || Train Loss: 0.0158 || Test Loss: 0.0153
# Epoch 391 || batch 50 || Loss: 0.0151
# Epoch 391/1000 || Train Loss: 0.0157 || Test Loss: 0.0152
# Epoch 392 || batch 50 || Loss: 0.0152
# Epoch 392/1000 || Train Loss: 0.0157 || Test Loss: 0.0158
# Epoch 393 || batch 50 || Loss: 0.0159
# Epoch 393/1000 || Train Loss: 0.0156 || Test Loss: 0.0151
# Epoch 394 || batch 50 || Loss: 0.0150
# Epoch 394/1000 || Train Loss: 0.0155 || Test Loss: 0.0151
# Epoch 395 || batch 50 || Loss: 0.0149
# Epoch 395/1000 || Train Loss: 0.0155 || Test Loss: 0.0157
# Epoch 396 || batch 50 || Loss: 0.0158
# Epoch 396/1000 || Train Loss: 0.0155 || Test Loss: 0.0150
# Epoch 397 || batch 50 || Loss: 0.0157
# Epoch 397/1000 || Train Loss: 0.0155 || Test Loss: 0.0150
# Epoch 398 || batch 50 || Loss: 0.0148
# Epoch 398/1000 || Train Loss: 0.0154 || Test Loss: 0.0149
# Epoch 399 || batch 50 || Loss: 0.0156
# Epoch 399/1000 || Train Loss: 0.0153 || Test Loss: 0.0149
# Epoch 400 || batch 50 || Loss: 0.0156
# Epoch 400/1000 || Train Loss: 0.0153 || Test Loss: 0.0148
# Epoch 401 || batch 50 || Loss: 0.0156
# Epoch 401/1000 || Train Loss: 0.0153 || Test Loss: 0.0155
# Epoch 402 || batch 50 || Loss: 0.0145
# Epoch 402/1000 || Train Loss: 0.0153 || Test Loss: 0.0147
# Epoch 403 || batch 50 || Loss: 0.0138
# Epoch 403/1000 || Train Loss: 0.0152 || Test Loss: 0.0147
# Epoch 404 || batch 50 || Loss: 0.0155
# Epoch 404/1000 || Train Loss: 0.0151 || Test Loss: 0.0147
# Epoch 405 || batch 50 || Loss: 0.0154
# Epoch 405/1000 || Train Loss: 0.0151 || Test Loss: 0.0146
# Epoch 406 || batch 50 || Loss: 0.0153
# Epoch 406/1000 || Train Loss: 0.0151 || Test Loss: 0.0146
# Epoch 407 || batch 50 || Loss: 0.0151
# Epoch 407/1000 || Train Loss: 0.0148 || Test Loss: 0.0145
# Epoch 408 || batch 50 || Loss: 0.0153
# Epoch 408/1000 || Train Loss: 0.0150 || Test Loss: 0.0145
# Epoch 409 || batch 50 || Loss: 0.0142
# Epoch 409/1000 || Train Loss: 0.0150 || Test Loss: 0.0144
# Epoch 410 || batch 50 || Loss: 0.0151
# Epoch 410/1000 || Train Loss: 0.0149 || Test Loss: 0.0144
# Epoch 411 || batch 50 || Loss: 0.0142
# Epoch 411/1000 || Train Loss: 0.0157 || Test Loss: 0.0145
# Epoch 412 || batch 50 || Loss: 0.0151
# Epoch 412/1000 || Train Loss: 0.0149 || Test Loss: 0.0143
# Epoch 413 || batch 50 || Loss: 0.0151
# Epoch 413/1000 || Train Loss: 0.0148 || Test Loss: 0.0143
# Epoch 414 || batch 50 || Loss: 0.0151
# Epoch 414/1000 || Train Loss: 0.0147 || Test Loss: 0.0143
# Epoch 415 || batch 50 || Loss: 0.0150
# Epoch 415/1000 || Train Loss: 0.0147 || Test Loss: 0.0142
# Epoch 416 || batch 50 || Loss: 0.0149
# Epoch 416/1000 || Train Loss: 0.0147 || Test Loss: 0.0142
# Epoch 417 || batch 50 || Loss: 0.0149
# Epoch 417/1000 || Train Loss: 0.0146 || Test Loss: 0.0141
# Epoch 418 || batch 50 || Loss: 0.0149
# Epoch 418/1000 || Train Loss: 0.0146 || Test Loss: 0.0141
# Epoch 419 || batch 50 || Loss: 0.0140
# Epoch 419/1000 || Train Loss: 0.0154 || Test Loss: 0.0142
# Epoch 420 || batch 50 || Loss: 0.0138
# Epoch 420/1000 || Train Loss: 0.0144 || Test Loss: 0.0141
# Epoch 421 || batch 50 || Loss: 0.0148
# Epoch 421/1000 || Train Loss: 0.0145 || Test Loss: 0.0140
# Epoch 422 || batch 50 || Loss: 0.0148
# Epoch 422/1000 || Train Loss: 0.0144 || Test Loss: 0.0139
# Epoch 423 || batch 50 || Loss: 0.0136
# Epoch 423/1000 || Train Loss: 0.0144 || Test Loss: 0.0139
# Epoch 424 || batch 50 || Loss: 0.0148
# Epoch 424/1000 || Train Loss: 0.0143 || Test Loss: 0.0139
# Epoch 425 || batch 50 || Loss: 0.0147
# Epoch 425/1000 || Train Loss: 0.0143 || Test Loss: 0.0138
# Epoch 426 || batch 50 || Loss: 0.0136
# Epoch 426/1000 || Train Loss: 0.0151 || Test Loss: 0.0139
# Epoch 427 || batch 50 || Loss: 0.0145
# Epoch 427/1000 || Train Loss: 0.0143 || Test Loss: 0.0138
# Epoch 428 || batch 50 || Loss: 0.0144
# Epoch 428/1000 || Train Loss: 0.0142 || Test Loss: 0.0137
# Epoch 429 || batch 50 || Loss: 0.0145
# Epoch 429/1000 || Train Loss: 0.0142 || Test Loss: 0.0137
# Epoch 430 || batch 50 || Loss: 0.0144
# Epoch 430/1000 || Train Loss: 0.0141 || Test Loss: 0.0137
# Epoch 431 || batch 50 || Loss: 0.0136
# Epoch 431/1000 || Train Loss: 0.0141 || Test Loss: 0.0136
# Epoch 432 || batch 50 || Loss: 0.0142
# Epoch 432/1000 || Train Loss: 0.0141 || Test Loss: 0.0136
# Epoch 433 || batch 50 || Loss: 0.0144
# Epoch 433/1000 || Train Loss: 0.0140 || Test Loss: 0.0135
# Epoch 434 || batch 50 || Loss: 0.0134
# Epoch 434/1000 || Train Loss: 0.0140 || Test Loss: 0.0135
# Epoch 435 || batch 50 || Loss: 0.0142
# Epoch 435/1000 || Train Loss: 0.0140 || Test Loss: 0.0135
# Epoch 436 || batch 50 || Loss: 0.0142
# Epoch 436/1000 || Train Loss: 0.0139 || Test Loss: 0.0135
# Epoch 437 || batch 50 || Loss: 0.0133
# Epoch 437/1000 || Train Loss: 0.0139 || Test Loss: 0.0135
# Epoch 438 || batch 50 || Loss: 0.0142
# Epoch 438/1000 || Train Loss: 0.0138 || Test Loss: 0.0134
# Epoch 439 || batch 50 || Loss: 0.0133
# Epoch 439/1000 || Train Loss: 0.0138 || Test Loss: 0.0134
# Epoch 440 || batch 50 || Loss: 0.0123
# Epoch 440/1000 || Train Loss: 0.0146 || Test Loss: 0.0134
# Epoch 441 || batch 50 || Loss: 0.0142
# Epoch 441/1000 || Train Loss: 0.0139 || Test Loss: 0.0133
# Epoch 442 || batch 50 || Loss: 0.0132
# Epoch 442/1000 || Train Loss: 0.0138 || Test Loss: 0.0133
# Epoch 443 || batch 50 || Loss: 0.0128
# Epoch 443/1000 || Train Loss: 0.0137 || Test Loss: 0.0132
# Epoch 444 || batch 50 || Loss: 0.0140
# Epoch 444/1000 || Train Loss: 0.0137 || Test Loss: 0.0132
# Epoch 445 || batch 50 || Loss: 0.0140
# Epoch 445/1000 || Train Loss: 0.0136 || Test Loss: 0.0131
# Epoch 446 || batch 50 || Loss: 0.0139
# Epoch 446/1000 || Train Loss: 0.0136 || Test Loss: 0.0131
# Epoch 447 || batch 50 || Loss: 0.0139
# Epoch 447/1000 || Train Loss: 0.0136 || Test Loss: 0.0131
# Epoch 448 || batch 50 || Loss: 0.0138
# Epoch 448/1000 || Train Loss: 0.0135 || Test Loss: 0.0131
# Epoch 449 || batch 50 || Loss: 0.0138
# Epoch 449/1000 || Train Loss: 0.0135 || Test Loss: 0.0130
# Epoch 450 || batch 50 || Loss: 0.0129
# Epoch 450/1000 || Train Loss: 0.0142 || Test Loss: 0.0130
# Epoch 451 || batch 50 || Loss: 0.0138
# Epoch 451/1000 || Train Loss: 0.0135 || Test Loss: 0.0130
# Epoch 452 || batch 50 || Loss: 0.0137
# Epoch 452/1000 || Train Loss: 0.0134 || Test Loss: 0.0129
# Epoch 453 || batch 50 || Loss: 0.0136
# Epoch 453/1000 || Train Loss: 0.0134 || Test Loss: 0.0136
# Epoch 454 || batch 50 || Loss: 0.0127
# Epoch 454/1000 || Train Loss: 0.0133 || Test Loss: 0.0129
# Epoch 455 || batch 50 || Loss: 0.0136
# Epoch 455/1000 || Train Loss: 0.0133 || Test Loss: 0.0128
# Epoch 456 || batch 50 || Loss: 0.0136
# Epoch 456/1000 || Train Loss: 0.0132 || Test Loss: 0.0128
# Epoch 457 || batch 50 || Loss: 0.0124
# Epoch 457/1000 || Train Loss: 0.0133 || Test Loss: 0.0128
# Epoch 458 || batch 50 || Loss: 0.0136
# Epoch 458/1000 || Train Loss: 0.0132 || Test Loss: 0.0127
# Epoch 459 || batch 50 || Loss: 0.0126
# Epoch 459/1000 || Train Loss: 0.0132 || Test Loss: 0.0127
# Epoch 460 || batch 50 || Loss: 0.0126
# Epoch 460/1000 || Train Loss: 0.0132 || Test Loss: 0.0127
# Epoch 461 || batch 50 || Loss: 0.0134
# Epoch 461/1000 || Train Loss: 0.0131 || Test Loss: 0.0127
# Epoch 462 || batch 50 || Loss: 0.0134
# Epoch 462/1000 || Train Loss: 0.0131 || Test Loss: 0.0126
# Epoch 463 || batch 50 || Loss: 0.0134
# Epoch 463/1000 || Train Loss: 0.0130 || Test Loss: 0.0126
# Epoch 464 || batch 50 || Loss: 0.0134
# Epoch 464/1000 || Train Loss: 0.0130 || Test Loss: 0.0126
# Epoch 465 || batch 50 || Loss: 0.0122
# Epoch 465/1000 || Train Loss: 0.0130 || Test Loss: 0.0125
# Epoch 466 || batch 50 || Loss: 0.0122
# Epoch 466/1000 || Train Loss: 0.0130 || Test Loss: 0.0125
# Epoch 467 || batch 50 || Loss: 0.0133
# Epoch 467/1000 || Train Loss: 0.0129 || Test Loss: 0.0125
# Epoch 468 || batch 50 || Loss: 0.0132
# Epoch 468/1000 || Train Loss: 0.0129 || Test Loss: 0.0124
# Epoch 469 || batch 50 || Loss: 0.0132
# Epoch 469/1000 || Train Loss: 0.0129 || Test Loss: 0.0124
# Epoch 470 || batch 50 || Loss: 0.0131
# Epoch 470/1000 || Train Loss: 0.0129 || Test Loss: 0.0124
# Epoch 471 || batch 50 || Loss: 0.0131
# Epoch 471/1000 || Train Loss: 0.0129 || Test Loss: 0.0124
# Epoch 472 || batch 50 || Loss: 0.0122
# Epoch 472/1000 || Train Loss: 0.0128 || Test Loss: 0.0123
# Epoch 473 || batch 50 || Loss: 0.0131
# Epoch 473/1000 || Train Loss: 0.0128 || Test Loss: 0.0123
# Epoch 474 || batch 50 || Loss: 0.0130
# Epoch 474/1000 || Train Loss: 0.0127 || Test Loss: 0.0123
# Epoch 475 || batch 50 || Loss: 0.0130
# Epoch 475/1000 || Train Loss: 0.0127 || Test Loss: 0.0122
# Epoch 476 || batch 50 || Loss: 0.0129
# Epoch 476/1000 || Train Loss: 0.0127 || Test Loss: 0.0122
# Epoch 477 || batch 50 || Loss: 0.0130
# Epoch 477/1000 || Train Loss: 0.0127 || Test Loss: 0.0122
# Epoch 478 || batch 50 || Loss: 0.0129
# Epoch 478/1000 || Train Loss: 0.0126 || Test Loss: 0.0122
# Epoch 479 || batch 50 || Loss: 0.0129
# Epoch 479/1000 || Train Loss: 0.0126 || Test Loss: 0.0122
# Epoch 480 || batch 50 || Loss: 0.0119
# Epoch 480/1000 || Train Loss: 0.0126 || Test Loss: 0.0121
# Epoch 481 || batch 50 || Loss: 0.0129
# Epoch 481/1000 || Train Loss: 0.0125 || Test Loss: 0.0121
# Epoch 482 || batch 50 || Loss: 0.0128
# Epoch 482/1000 || Train Loss: 0.0126 || Test Loss: 0.0121
# Epoch 483 || batch 50 || Loss: 0.0128
# Epoch 483/1000 || Train Loss: 0.0125 || Test Loss: 0.0120
# Epoch 484 || batch 50 || Loss: 0.0119
# Epoch 484/1000 || Train Loss: 0.0125 || Test Loss: 0.0120
# Epoch 485 || batch 50 || Loss: 0.0127
# Epoch 485/1000 || Train Loss: 0.0125 || Test Loss: 0.0120
# Epoch 486 || batch 50 || Loss: 0.0128
# Epoch 486/1000 || Train Loss: 0.0124 || Test Loss: 0.0120
# Epoch 487 || batch 50 || Loss: 0.0126
# Epoch 487/1000 || Train Loss: 0.0124 || Test Loss: 0.0119
# Epoch 488 || batch 50 || Loss: 0.0127
# Epoch 488/1000 || Train Loss: 0.0124 || Test Loss: 0.0119
# Epoch 489 || batch 50 || Loss: 0.0127
# Epoch 489/1000 || Train Loss: 0.0123 || Test Loss: 0.0119
# Epoch 490 || batch 50 || Loss: 0.0126
# Epoch 490/1000 || Train Loss: 0.0123 || Test Loss: 0.0118
# Epoch 491 || batch 50 || Loss: 0.0126
# Epoch 491/1000 || Train Loss: 0.0123 || Test Loss: 0.0124
# Epoch 492 || batch 50 || Loss: 0.0126
# Epoch 492/1000 || Train Loss: 0.0123 || Test Loss: 0.0118
# Epoch 493 || batch 50 || Loss: 0.0124
# Epoch 493/1000 || Train Loss: 0.0121 || Test Loss: 0.0118
# Epoch 494 || batch 50 || Loss: 0.0126
# Epoch 494/1000 || Train Loss: 0.0122 || Test Loss: 0.0117
# Epoch 495 || batch 50 || Loss: 0.0125
# Epoch 495/1000 || Train Loss: 0.0122 || Test Loss: 0.0117
# Epoch 496 || batch 50 || Loss: 0.0124
# Epoch 496/1000 || Train Loss: 0.0122 || Test Loss: 0.0117
# Epoch 497 || batch 50 || Loss: 0.0124
# Epoch 497/1000 || Train Loss: 0.0122 || Test Loss: 0.0117
# Epoch 498 || batch 50 || Loss: 0.0115
# Epoch 498/1000 || Train Loss: 0.0121 || Test Loss: 0.0116
# Epoch 499 || batch 50 || Loss: 0.0109
# Epoch 499/1000 || Train Loss: 0.0121 || Test Loss: 0.0116
# Epoch 500 || batch 50 || Loss: 0.0124
# Epoch 500/1000 || Train Loss: 0.0121 || Test Loss: 0.0116
# ...
# Epoch 835 || batch 50 || Loss: 0.0071
# Epoch 835/1000 || Train Loss: 0.0086 || Test Loss: 0.0073
# Epoch 836 || batch 50 || Loss: 0.0080
# Epoch 836/1000 || Train Loss: 0.0078 || Test Loss: 0.0073
# Epoch 837 || batch 50 || Loss: 0.0080
# Epoch 837/1000 || Train Loss: 0.0077 || Test Loss: 0.0073
# Epoch 838 || batch 50 || Loss: 0.0071
# Epoch 838/1000 || Train Loss: 0.0077 || Test Loss: 0.0073
# Epoch 839 || batch 50 || Loss: 0.0080
# Epoch 839/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 840 || batch 50 || Loss: 0.0080
# Epoch 840/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 841 || batch 50 || Loss: 0.0080
# Epoch 841/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 842 || batch 50 || Loss: 0.0080
# Epoch 842/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 843 || batch 50 || Loss: 0.0080
# Epoch 843/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 844 || batch 50 || Loss: 0.0080
# Epoch 844/1000 || Train Loss: 0.0076 || Test Loss: 0.0072
# Epoch 845 || batch 50 || Loss: 0.0080
# Epoch 845/1000 || Train Loss: 0.0076 || Test Loss: 0.0072
# Epoch 846 || batch 50 || Loss: 0.0077
# Epoch 846/1000 || Train Loss: 0.0074 || Test Loss: 0.0072
# Epoch 847 || batch 50 || Loss: 0.0069
# Epoch 847/1000 || Train Loss: 0.0085 || Test Loss: 0.0073
# Epoch 848 || batch 50 || Loss: 0.0066
# Epoch 848/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 849 || batch 50 || Loss: 0.0080
# Epoch 849/1000 || Train Loss: 0.0077 || Test Loss: 0.0072
# Epoch 850 || batch 50 || Loss: 0.0079
# Epoch 850/1000 || Train Loss: 0.0076 || Test Loss: 0.0072
# Epoch 851 || batch 50 || Loss: 0.0079
# Epoch 851/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 852 || batch 50 || Loss: 0.0070
# Epoch 852/1000 || Train Loss: 0.0076 || Test Loss: 0.0072
# Epoch 853 || batch 50 || Loss: 0.0079
# Epoch 853/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 854 || batch 50 || Loss: 0.0079
# Epoch 854/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 855 || batch 50 || Loss: 0.0079
# Epoch 855/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 856 || batch 50 || Loss: 0.0079
# Epoch 856/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 857 || batch 50 || Loss: 0.0079
# Epoch 857/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 858 || batch 50 || Loss: 0.0069
# Epoch 858/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 859 || batch 50 || Loss: 0.0078
# Epoch 859/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 860 || batch 50 || Loss: 0.0069
# Epoch 860/1000 || Train Loss: 0.0085 || Test Loss: 0.0072
# Epoch 861 || batch 50 || Loss: 0.0079
# Epoch 861/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 862 || batch 50 || Loss: 0.0067
# Epoch 862/1000 || Train Loss: 0.0075 || Test Loss: 0.0071
# Epoch 863 || batch 50 || Loss: 0.0078
# Epoch 863/1000 || Train Loss: 0.0075 || Test Loss: 0.0071
# Epoch 864 || batch 50 || Loss: 0.0060
# Epoch 864/1000 || Train Loss: 0.0075 || Test Loss: 0.0071
# Epoch 865 || batch 50 || Loss: 0.0078
# Epoch 865/1000 || Train Loss: 0.0075 || Test Loss: 0.0071
# Epoch 866 || batch 50 || Loss: 0.0078
# Epoch 866/1000 || Train Loss: 0.0075 || Test Loss: 0.0071
# Epoch 867 || batch 50 || Loss: 0.0078
# Epoch 867/1000 || Train Loss: 0.0075 || Test Loss: 0.0071
# Epoch 868 || batch 50 || Loss: 0.0068
# Epoch 868/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 869 || batch 50 || Loss: 0.0078
# Epoch 869/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 870 || batch 50 || Loss: 0.0078
# Epoch 870/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 871 || batch 50 || Loss: 0.0078
# Epoch 871/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 872 || batch 50 || Loss: 0.0075
# Epoch 872/1000 || Train Loss: 0.0072 || Test Loss: 0.0070
# Epoch 873 || batch 50 || Loss: 0.0078
# Epoch 873/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 874 || batch 50 || Loss: 0.0078
# Epoch 874/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 875 || batch 50 || Loss: 0.0069
# Epoch 875/1000 || Train Loss: 0.0082 || Test Loss: 0.0071
# Epoch 876 || batch 50 || Loss: 0.0078
# Epoch 876/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 877 || batch 50 || Loss: 0.0078
# Epoch 877/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 878 || batch 50 || Loss: 0.0078
# Epoch 878/1000 || Train Loss: 0.0075 || Test Loss: 0.0070
# Epoch 879 || batch 50 || Loss: 0.0077
# Epoch 879/1000 || Train Loss: 0.0074 || Test Loss: 0.0070
# Epoch 880 || batch 50 || Loss: 0.0069
# Epoch 880/1000 || Train Loss: 0.0074 || Test Loss: 0.0070
# Epoch 881 || batch 50 || Loss: 0.0077
# Epoch 881/1000 || Train Loss: 0.0074 || Test Loss: 0.0070
# Epoch 882 || batch 50 || Loss: 0.0067
# Epoch 882/1000 || Train Loss: 0.0074 || Test Loss: 0.0070
# Epoch 883 || batch 50 || Loss: 0.0077
# Epoch 883/1000 || Train Loss: 0.0074 || Test Loss: 0.0070
# Epoch 884 || batch 50 || Loss: 0.0066
# Epoch 884/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 885 || batch 50 || Loss: 0.0068
# Epoch 885/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 886 || batch 50 || Loss: 0.0068
# Epoch 886/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 887 || batch 50 || Loss: 0.0077
# Epoch 887/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 888 || batch 50 || Loss: 0.0077
# Epoch 888/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 889 || batch 50 || Loss: 0.0076
# Epoch 889/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 890 || batch 50 || Loss: 0.0066
# Epoch 890/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 891 || batch 50 || Loss: 0.0077
# Epoch 891/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 892 || batch 50 || Loss: 0.0068
# Epoch 892/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 893 || batch 50 || Loss: 0.0067
# Epoch 893/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 894 || batch 50 || Loss: 0.0076
# Epoch 894/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 895 || batch 50 || Loss: 0.0076
# Epoch 895/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 896 || batch 50 || Loss: 0.0068
# Epoch 896/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 897 || batch 50 || Loss: 0.0076
# Epoch 897/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 898 || batch 50 || Loss: 0.0068
# Epoch 898/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 899 || batch 50 || Loss: 0.0074
# Epoch 899/1000 || Train Loss: 0.0071 || Test Loss: 0.0069
# Epoch 900 || batch 50 || Loss: 0.0076
# Epoch 900/1000 || Train Loss: 0.0073 || Test Loss: 0.0069
# Epoch 901 || batch 50 || Loss: 0.0068
# Epoch 901/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 902 || batch 50 || Loss: 0.0060
# Epoch 902/1000 || Train Loss: 0.0081 || Test Loss: 0.0069
# Epoch 903 || batch 50 || Loss: 0.0077
# Epoch 903/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 904 || batch 50 || Loss: 0.0076
# Epoch 904/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 905 || batch 50 || Loss: 0.0076
# Epoch 905/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 906 || batch 50 || Loss: 0.0076
# Epoch 906/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 907 || batch 50 || Loss: 0.0076
# Epoch 907/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 908 || batch 50 || Loss: 0.0067
# Epoch 908/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 909 || batch 50 || Loss: 0.0067
# Epoch 909/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 910 || batch 50 || Loss: 0.0075
# Epoch 910/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 911 || batch 50 || Loss: 0.0075
# Epoch 911/1000 || Train Loss: 0.0073 || Test Loss: 0.0068
# Epoch 912 || batch 50 || Loss: 0.0073
# Epoch 912/1000 || Train Loss: 0.0071 || Test Loss: 0.0068
# Epoch 913 || batch 50 || Loss: 0.0059
# Epoch 913/1000 || Train Loss: 0.0071 || Test Loss: 0.0068
# Epoch 914 || batch 50 || Loss: 0.0075
# Epoch 914/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 915 || batch 50 || Loss: 0.0075
# Epoch 915/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 916 || batch 50 || Loss: 0.0066
# Epoch 916/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 917 || batch 50 || Loss: 0.0075
# Epoch 917/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 918 || batch 50 || Loss: 0.0075
# Epoch 918/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 919 || batch 50 || Loss: 0.0067
# Epoch 919/1000 || Train Loss: 0.0072 || Test Loss: 0.0067
# Epoch 920 || batch 50 || Loss: 0.0067
# Epoch 920/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 921 || batch 50 || Loss: 0.0067
# Epoch 921/1000 || Train Loss: 0.0079 || Test Loss: 0.0068
# Epoch 922 || batch 50 || Loss: 0.0075
# Epoch 922/1000 || Train Loss: 0.0072 || Test Loss: 0.0068
# Epoch 923 || batch 50 || Loss: 0.0075
# Epoch 923/1000 || Train Loss: 0.0072 || Test Loss: 0.0067
# Epoch 924 || batch 50 || Loss: 0.0075
# Epoch 924/1000 || Train Loss: 0.0072 || Test Loss: 0.0067
# Epoch 925 || batch 50 || Loss: 0.0065
# Epoch 925/1000 || Train Loss: 0.0072 || Test Loss: 0.0067
# Epoch 926 || batch 50 || Loss: 0.0074
# Epoch 926/1000 || Train Loss: 0.0072 || Test Loss: 0.0067
# Epoch 927 || batch 50 || Loss: 0.0074
# Epoch 927/1000 || Train Loss: 0.0072 || Test Loss: 0.0067
# Epoch 928 || batch 50 || Loss: 0.0066
# Epoch 928/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 929 || batch 50 || Loss: 0.0075
# Epoch 929/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 930 || batch 50 || Loss: 0.0059
# Epoch 930/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 931 || batch 50 || Loss: 0.0074
# Epoch 931/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 932 || batch 50 || Loss: 0.0075
# Epoch 932/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 933 || batch 50 || Loss: 0.0074
# Epoch 933/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 934 || batch 50 || Loss: 0.0074
# Epoch 934/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 935 || batch 50 || Loss: 0.0063
# Epoch 935/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 936 || batch 50 || Loss: 0.0074
# Epoch 936/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 937 || batch 50 || Loss: 0.0074
# Epoch 937/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 938 || batch 50 || Loss: 0.0074
# Epoch 938/1000 || Train Loss: 0.0071 || Test Loss: 0.0067
# Epoch 939 || batch 50 || Loss: 0.0074
# Epoch 939/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 940 || batch 50 || Loss: 0.0074
# Epoch 940/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 941 || batch 50 || Loss: 0.0074
# Epoch 941/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 942 || batch 50 || Loss: 0.0064
# Epoch 942/1000 || Train Loss: 0.0080 || Test Loss: 0.0067
# Epoch 943 || batch 50 || Loss: 0.0074
# Epoch 943/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 944 || batch 50 || Loss: 0.0074
# Epoch 944/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 945 || batch 50 || Loss: 0.0073
# Epoch 945/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 946 || batch 50 || Loss: 0.0073
# Epoch 946/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 947 || batch 50 || Loss: 0.0071
# Epoch 947/1000 || Train Loss: 0.0069 || Test Loss: 0.0066
# Epoch 948 || batch 50 || Loss: 0.0073
# Epoch 948/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 949 || batch 50 || Loss: 0.0073
# Epoch 949/1000 || Train Loss: 0.0071 || Test Loss: 0.0066
# Epoch 950 || batch 50 || Loss: 0.0062
# Epoch 950/1000 || Train Loss: 0.0070 || Test Loss: 0.0072
# Epoch 951 || batch 50 || Loss: 0.0064
# Epoch 951/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 952 || batch 50 || Loss: 0.0073
# Epoch 952/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 953 || batch 50 || Loss: 0.0073
# Epoch 953/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 954 || batch 50 || Loss: 0.0064
# Epoch 954/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 955 || batch 50 || Loss: 0.0073
# Epoch 955/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 956 || batch 50 || Loss: 0.0073
# Epoch 956/1000 || Train Loss: 0.0070 || Test Loss: 0.0066
# Epoch 957 || batch 50 || Loss: 0.0073
# Epoch 957/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 958 || batch 50 || Loss: 0.0064
# Epoch 958/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 959 || batch 50 || Loss: 0.0073
# Epoch 959/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 960 || batch 50 || Loss: 0.0065
# Epoch 960/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 961 || batch 50 || Loss: 0.0073
# Epoch 961/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 962 || batch 50 || Loss: 0.0073
# Epoch 962/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 963 || batch 50 || Loss: 0.0062
# Epoch 963/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 964 || batch 50 || Loss: 0.0073
# Epoch 964/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 965 || batch 50 || Loss: 0.0073
# Epoch 965/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 966 || batch 50 || Loss: 0.0073
# Epoch 966/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 967 || batch 50 || Loss: 0.0063
# Epoch 967/1000 || Train Loss: 0.0070 || Test Loss: 0.0065
# Epoch 968 || batch 50 || Loss: 0.0062
# Epoch 968/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 969 || batch 50 || Loss: 0.0073
# Epoch 969/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 970 || batch 50 || Loss: 0.0072
# Epoch 970/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 971 || batch 50 || Loss: 0.0072
# Epoch 971/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 972 || batch 50 || Loss: 0.0073
# Epoch 972/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 973 || batch 50 || Loss: 0.0072
# Epoch 973/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 974 || batch 50 || Loss: 0.0072
# Epoch 974/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 975 || batch 50 || Loss: 0.0073
# Epoch 975/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 976 || batch 50 || Loss: 0.0064
# Epoch 976/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 977 || batch 50 || Loss: 0.0072
# Epoch 977/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 978 || batch 50 || Loss: 0.0072
# Epoch 978/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 979 || batch 50 || Loss: 0.0072
# Epoch 979/1000 || Train Loss: 0.0069 || Test Loss: 0.0070
# Epoch 980 || batch 50 || Loss: 0.0055
# Epoch 980/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 981 || batch 50 || Loss: 0.0063
# Epoch 981/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 982 || batch 50 || Loss: 0.0060
# Epoch 982/1000 || Train Loss: 0.0075 || Test Loss: 0.0065
# Epoch 983 || batch 50 || Loss: 0.0072
# Epoch 983/1000 || Train Loss: 0.0069 || Test Loss: 0.0065
# Epoch 984 || batch 50 || Loss: 0.0072
# Epoch 984/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 985 || batch 50 || Loss: 0.0071
# Epoch 985/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 986 || batch 50 || Loss: 0.0072
# Epoch 986/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 987 || batch 50 || Loss: 0.0072
# Epoch 987/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 988 || batch 50 || Loss: 0.0071
# Epoch 988/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 989 || batch 50 || Loss: 0.0071
# Epoch 989/1000 || Train Loss: 0.0068 || Test Loss: 0.0064
# Epoch 990 || batch 50 || Loss: 0.0071
# Epoch 990/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 991 || batch 50 || Loss: 0.0071
# Epoch 991/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 992 || batch 50 || Loss: 0.0071
# Epoch 992/1000 || Train Loss: 0.0069 || Test Loss: 0.0064
# Epoch 993 || batch 50 || Loss: 0.0071
# Epoch 993/1000 || Train Loss: 0.0068 || Test Loss: 0.0064
# Epoch 994 || batch 50 || Loss: 0.0052
# Epoch 994/1000 || Train Loss: 0.0068 || Test Loss: 0.0064
# Epoch 995 || batch 50 || Loss: 0.0071
# Epoch 995/1000 || Train Loss: 0.0068 || Test Loss: 0.0064
# Epoch 996 || batch 50 || Loss: 0.0062
# Epoch 996/1000 || Train Loss: 0.0068 || Test Loss: 0.0064
# Epoch 997 || batch 50 || Loss: 0.0071
# Epoch 997/1000 || Train Loss: 0.0068 || Test Loss: 0.0063
# Epoch 998 || batch 50 || Loss: 0.0071
# Epoch 998/1000 || Train Loss: 0.0068 || Test Loss: 0.0064
# Epoch 999 || batch 50 || Loss: 0.0071
# Epoch 999/1000 || Train Loss: 0.0068 || Test Loss: 0.0063
# Epoch 1000 || batch 50 || Loss: 0.0071
# Epoch 1000/1000 || Train Loss: 0.0068 || Test Loss: 0.0063
# Training Complete.

# %%
## Test Predictive Accuracy
def test_cbow(test_data, model, sample_size=None, seed=42, use_gpu=False):
    ## Random State
    np.random.seed(seed)
    ## Count Correct Answers
    correct_ct = 0
    ## Downsample if Desired (To Save Time)
    if sample_size is None:
        sample = test_data
    else:
        sample = np.random.choice(len(test_data), sample_size, replace=False)
        sample = [test_data[s] for s in sample]
    ## Evaluate
    model.eval()
    for ctx_var, target in get_cbow_batches(sample, 1):
        if use_gpu:
            ctx_var = ctx_var.cuda()
        model.zero_grad()
        log_probs = model(ctx_var)
        if use_gpu:
            log_probs = log_probs.cpu()
        #_, predicted = torch.max(log_probs[0], 1)
        predicted = torch.argmax(log_probs[0])
        if torch.eq(predicted, target[0]):
            correct_ct += 1
            
    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(sample)*100, correct_ct, len(sample)))

test_cbow(cbow_train, cbow_model, sample_size=min(5000, len(cbow_train)), use_gpu=torch.cuda.is_available())
test_cbow(cbow_test, cbow_model, sample_size=min(5000, len(cbow_test)), use_gpu=torch.cuda.is_available())
# Out:
# Accuracy: 99.8% (1088/1090)
# Accuracy: 99.8% (1088/1090)

# %%
showPlot('CBOW Losses',cbow_losses,cbow_test_losses)

# %% [markdown]
# ## Skip-gram Implementation

# %% [markdown]
# We've now trained an embedding using the continuous bag of words model. Below, we also show code for training the opposite model - the skipgram model - where you predict the context words based on a target word.
#
# Note how simple the SkipGram network is. There are no linear layers - just the embedding layer, and the training simply aims to maximize the dot product of embeddings of the target and embedding words.

# %% [markdown]
# #### Dataset Generation
#
# We provide the beginning of a function for generating the skipgram dataset. You need to implement negative sampling.

# %%
# Tuple of a word (the target) to a word (a context word)
def create_skipgram_dataset(documents, context_size, k_negative=5):
    data = []
    for document in documents:
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        for i in range(context_size, len(document) - context_size):
            word_set = set()
            for j in range(1, context_size+1):
                data.append((document[i], document[i-j], 1))
                data.append((document[i], document[i+j], 1))

            ##TODO: Implement negative sampling
            for _ in range(k_negative):
                rand_id = random.randint(0, vocab_size-1)
                if not rand_id in word_set:
                    data.append((document[i], i2w[rand_id], 0))
    return data

## Create Datasets
skipgram_train = create_skipgram_dataset(documents_train, context_size=CONTEXT_SIZE, k_negative=5)
skipgram_test = create_skipgram_dataset(documents_test, context_size=CONTEXT_SIZE, k_negative=5)

## Show Samples
print('skipgram sample', skipgram_train[:10])
# Out:
# skipgram sample [('once', 'EOS', 1), ('once', 'upon', 1), ('once', 'EOS', 1), ('once', 'a', 1), ('once', 'then', 0), ('once', 'name', 0), ('once', 'heaven', 0), ('once', 'distinctly', 0), ('once', 'lattice', 0), ('upon', 'once', 1)]

# %%
## Create Batches
def get_sgram_batches(data, batch_size):
    """

    """
    indices = np.arange(len(data))
    np.random.shuffle(indices)
    current_batch = []
    for i, indice in enumerate(indices):
        in_w, out_w, target = data[indice]
        in_w_var = torch.LongTensor([w2i[in_w]])
        out_w_var = torch.LongTensor([w2i[out_w]])
        target_t = torch.Tensor([target])
        current_batch.append((in_w_var, out_w_var, target_t))
        if current_batch and len(current_batch) % batch_size == 0 or i == len(indices) - 1:
            batch_in_w_var = torch.stack([v[0] for v in current_batch])
            batch_out_w_var = torch.stack([v[1] for v in current_batch])
            batch_target = torch.stack([v[2] for v in current_batch])
            current_batch = []
            yield batch_in_w_var, batch_out_w_var, batch_target

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embd_size):
        super(SkipGram, self).__init__()
        #TODO implement layers shown in the picture above
        self.embedding = nn.Embedding(vocab_size, embd_size)

    def forward(self, focus, context):
        #TODO implement forward of SkipGram.
        embed_f = self.embedding(focus)
        embed_c = self.embedding(context)
        score = torch.mul(embed_f, embed_c).squeeze(1).sum(dim=1)
        probs = torch.sigmoid(score)
        return probs

# %%
def train_skipgram(train_data,
                   test_data,
                   model=None,
                   n_epoch=1000,
                   learning_rate=0.01,
                   batch_size=30,
                   embd_size=128,
                   print_every_step=None,
                   print_every_epoch=50,
                   random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Initialize Model
    if model is None:
        model = SkipGram(vocab_size, embd_size)
    ## Put on GPU
    if torch.cuda.is_available():
        model = model.cuda()
    ## Show Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate Loss Function
    loss_fn = nn.BCELoss()
    ## Loss Cache
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        for step, (in_w_var, out_w_var, target_t) in enumerate(get_sgram_batches(train_data, batch_size)):
            #TODO implement training procedure for SkipGram
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()

            model.zero_grad()
            probs = model(in_w_var, out_w_var)
            loss = loss_fn(probs, target_t.squeeze())
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            
            if print_every_step is not None and (step + 1) % print_every_step == 0:
                print("Epoch {} || Step {}/{} || Loss: {:.4f}".format(epoch+1, step+1, len(train_data), (total_loss / step+1)))
            
        if print_every_epoch is not None and (epoch + 1) % print_every_epoch == 0:
            print("Epoch {}/{} || Loss: {:.4f}".format(epoch+1, n_epoch, total_loss / (step+1)))
        model.eval()
        ##TODO Compute Losses
        train_loss = total_loss / (step+1)
        test_loss = 0
        for step1, (in_w_var1, out_w_var1, target_t1) in enumerate(get_sgram_batches(test_data, batch_size)):
            #TODO implement training procedure for SkipGram
            in_w_var1 = in_w_var1.cuda()
            out_w_var1 = out_w_var1.cuda()
            target_t1 = target_t1.cuda()

            probs1 = model(in_w_var1, out_w_var1)
            loss_t = loss_fn(probs1, target_t1.squeeze())
            test_loss += loss_t.item()
        test_loss = test_loss / (step1+1)
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete")
    return model, losses, test_losses

## Fit Model
sg_model, sg_losses, sg_tloss = train_skipgram(skipgram_train,
                                     skipgram_test,
                                     n_epoch=1000,
                                     learning_rate=0.01,
                                     batch_size=30,
                                     embd_size=128,
                                     print_every_step=None,
                                     print_every_epoch=50)
# Out:
# SkipGram(
#   (embedding): Embedding(435, 128)
# )
# Epoch 50/1000 || Loss: 5.0520
# Epoch 100/1000 || Loss: 3.9579
# Epoch 150/1000 || Loss: 3.5199
# Epoch 200/1000 || Loss: 3.3003
# Epoch 250/1000 || Loss: 3.1846
# Epoch 300/1000 || Loss: 3.1356
# Epoch 350/1000 || Loss: 3.1175
# Epoch 400/1000 || Loss: 3.1063
# Epoch 450/1000 || Loss: 3.0816
# Epoch 500/1000 || Loss: 3.0762
# Epoch 550/1000 || Loss: 3.0632
# Epoch 600/1000 || Loss: 3.0427
# Epoch 650/1000 || Loss: 3.0396
# Epoch 700/1000 || Loss: 3.0284
# Epoch 750/1000 || Loss: 3.0173
# Epoch 800/1000 || Loss: 2.9893
# Epoch 850/1000 || Loss: 2.9866
# Epoch 900/1000 || Loss: 2.9670
# Epoch 950/1000 || Loss: 2.9645
# Epoch 1000/1000 || Loss: 2.9627
# Training Complete

# %%
## Plot Losses
showPlot('SkipGram Losses', sg_losses, sg_tloss)

# %%
## Evaluate Accuracy
def test_skipgram(test_data, model):
    correct_ct = 0
    for in_w_var, out_w_var, target_t in get_sgram_batches(test_data, 1):

        if torch.cuda.is_available():
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()
        probs = model(in_w_var, out_w_var)
        predicted = (probs > 0.5)
        correct_ct += torch.sum(torch.eq(predicted[0], target_t))

    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(test_data)*100, correct_ct, len(test_data)))

test_skipgram(skipgram_train, sg_model)
test_skipgram(skipgram_test, sg_model)
# Out:
# Accuracy: 93.5% (9173/9810)
# Accuracy: 72.7% (7133/9810)

# %% [markdown]
# ### Semantic Similarity
# You are asked to write 2 functions. The first function `get_similarity` takes two terms in the vocabulary as arguments and returns their semantic similarity (cosine similarity). The second function `show_similar_terms` takes as an argument a term in the vocabulary and shows the top_k most similar terms based on cosine similarity. Use your functions to evaluate similarity of words in the Raven (based on your trained model) and some general words in the pretrained corpus.
#
# *Note:* Typically, word embeddings are typically trained on much larger datasets than the ones we provide. You will not necessarily see interpretable similarities below. We are primarily interested in your implementation. Accordingly, we provide code that loads pretrained word embeddings learned using 27 billion tweets. Learn more here: https://nlp.stanford.edu/projects/glove/

# %%
## Load Pretrained Vectors
glove_vectors = gensim.downloader.load('glove-twitter-25')

## Extract Embeddings and Vocab
glove_vocab = glove_vectors.index2word ## Note: If this doesn't work because of version < 4.0, use .index_to_key
glove_w2i = {w : i for i, w in enumerate(glove_vocab)}
glove_i2w = {i : w for i, w in enumerate(glove_vocab)}

## Convert Embeddings
glove_embeddings = nn.Embedding(len(glove_vocab), 25)
glove_embeddings = glove_embeddings.from_pretrained(torch.Tensor(glove_vectors.vectors))
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
def get_similarity(embeddings,
                   w2i,
                   term1,
                   term2):
    """

    """
    ## Check Terms
    for term in [term1, term2]:
        if term not in w2i:
            raise KeyError(f"Term `{term}` not found")
    ## Get Indices
    embeddings = embeddings.cpu()
    term1_ind = torch.LongTensor([w2i[term1]])
    term2_ind = torch.LongTensor([w2i[term2]])

  
    ##TODO: Retrieve Embeddings and Compute Cosine Similarity
    term1_embed, term2_embed = embeddings(term1_ind), embeddings(term2_ind)

    distance = float(cosine_distances(term1_embed.detach(), term2_embed.detach()))
    print(term1, term2, distance)

def show_similar_terms(embeddings, 
                       w2i,
                       i2w,
                       target_term,
                       top_k=10):
    """
    
    """
    ## Get Target Vector
    if target_term not in w2i:
        raise KeyError(f"Term `{target_term}` not in vocabulary")
    target_ind = torch.LongTensor([w2i[target_term]])
    ##TODO: Retrieve Embeddings for Target Term and Full Vocabulary
    ## Print out the top_k most similar terms based on cosine similarity
    embedding = embeddings(target_ind)
    cos_dis = np.array([cosine_distances(embeddings.weight[i,:].unsqueeze(dim=0).detach(), embedding.detach()) for i in range(embeddings.weight.shape[0])])
    cos_dis = cos_dis.flatten()
    top_terms = [i2w[i] for i in cos_dis.argsort()[1:top_k+1]]
    print(top_terms)

# %% [markdown]
# #### Evaluation
#
# First, evaluate similarity for embeddings trained using The Raven snippet. Then evaluate similarity in the pretrained embeddings.

# %%
## Evaluation for The Raven embeddings
get_similarity(cbow_model.embedding, w2i, "raven","nevermore")
get_similarity(cbow_model.embedding, w2i, "raven", "door")
show_similar_terms(cbow_model.embedding, w2i, i2w, "raven")

## Evaluation for The Raven Skipgram embeddings
get_similarity(sg_model.embedding, w2i, "raven","nevermore")
get_similarity(sg_model.embedding, w2i, "raven", "door")
show_similar_terms(sg_model.embedding, w2i, i2w, "raven")
# Out:
# raven nevermore 0.9213746190071106
# raven door 1.0904384851455688
# ['stillness', 'ghastly', 'respite', 'prophet', 'merely', 'decorum', 'shrieked', 'moment', 'wretch', 'stronger']
# raven nevermore 0.9367460012435913
# raven door 1.0082436800003052
# ['wished', 'forgiveness', 'faintly', 'rare', 'doubtless', 'our', 'at', 'feather', 'bust', 'front']

# %%
## Evaluation for Glove Embeddings
get_similarity(glove_embeddings, glove_w2i, "mouse","computer")
get_similarity(glove_embeddings, glove_w2i, "mouse","cat")
get_similarity(glove_embeddings, glove_w2i, "mouse","dog")
get_similarity(glove_embeddings, glove_w2i, "cat","dog")
show_similar_terms(glove_embeddings, glove_w2i, glove_i2w, "cat")
# Out:
# mouse computer 0.304571270942688
# mouse cat 0.16189134120941162
# mouse dog 0.23936331272125244
# cat dog 0.04091787338256836
# ['dog', 'monkey', 'bear', 'pet', 'girl', 'horse', 'kitty', 'puppy', 'hot', 'lady']

# %% [markdown]
# ##Evaluate large dataset

# %%
## Tokenize Data (We Recommend Developing your model using text_small first)
documents = list(map(tokenize, text_large))
# documents = list(map(tokenize, text_large))

## Flatten Sentences
documents = [tokens for d in documents for tokens in d]
print("Dataset Size:", len(documents))
# Out:
# Dataset Size: 80164

# %%
## Choose Frequency and Top Word Removal (Should Change This Depending on the Dataset)
MIN_FREQ = 0
RM_TOP = 0

## Get Vocabulary
vocab = [t for document in documents for t in document]
vocab_counts = Counter(vocab)
stopwords = set([s[0] for s in vocab_counts.most_common(RM_TOP)])
vocab = set([v for v in set(vocab) if vocab_counts[v] >= MIN_FREQ and v not in stopwords] + ["EOS"])
vocab_size = len(vocab)
print("Vocab Size:", vocab_size)

# Build a dictionary so that each word in vocabualary is assigned a number and 
# and we can map each number back to the word
w2i = {w: i for i, w in enumerate(sorted(vocab))}
i2w = {i: w for i, w in enumerate(sorted(vocab))}
# Out:
# Vocab Size: 65170

# %%
## Update The Documents with OOV Token
documents = [list(filter(lambda token: token in vocab, document)) for document in documents]

## Sample Training And Test Documents
np.random.seed(1)
documents_train = documents_test = documents
if len(documents) > 1:
    train_ind, test_ind = train_test_split(list(range(len(documents))))
    documents_train = [documents[t] for t in train_ind]
    documents_test = [documents[t] for t in test_ind]

# %% [markdown]
# ###CBOW

# %%
## Choose Context Size
CONTEXT_SIZE = 2

# Tuple of an array of words (the context) to a word (the target)
def create_cbow_dataset(documents, context_size):
    data = []
    for document in documents:
        ## Pad the sentence
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        ## Get Context Tokens
        for i in range(context_size, len(document) - context_size):
            target = document[i]
            before_ctx = []
            after_ctx = []
            for j in range(1,context_size+1):
                before_ctx.append(document[i - j])
                after_ctx.append(document[i + j])
            context = before_ctx + after_ctx
            data.append((context, target))
    return data

## Generate Datasets
cbow_train = create_cbow_dataset(documents_train, context_size=CONTEXT_SIZE)
cbow_test = create_cbow_dataset(documents_test, context_size=CONTEXT_SIZE)

## Show Samples
print('cbow train samples')
for i in range(5):
    print(cbow_train[i])
print("total train samples", len(cbow_train))
print("total test samples", len(cbow_test))
# Out:
# cbow train samples
# (['EOS', 'EOS', 'liberals', 'tend'], 'the')
# (['the', 'EOS', 'tend', 'to'], 'liberals')
# (['liberals', 'the', 'to', 'keep'], 'tend')
# (['tend', 'liberals', 'keep', 'to'], 'to')
# (['to', 'tend', 'to', 'themselves'], 'keep')
# total train samples 944039
# total test samples 314123

# %%
def train_cbow(train_data,
               test_data,
               model=None,
               n_epoch=100,
               embd_size=100,
               learning_rate=0.01,
               context_size=CONTEXT_SIZE,
               batch_size=50,
               hidden_size=128,
               print_every=None,
               random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Batch size
    batch_size = min(batch_size, len(train_data))
    ## Initialize New Model if Not Using Existing
    if model is None:
        model = CBOW(vocab_size, embd_size, context_size, hidden_size)
    ## GPU
    gpu_avail = torch.cuda.is_available()
    if gpu_avail:
        model = model.cuda()
    ## Show the Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate loss function
    loss_fn = nn.NLLLoss()
    ## Cache for Loss Values
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        model.train()
        for batch, (context, target) in enumerate(get_cbow_batches(train_data, batch_size)):
            ##TODO implement training procedure for CBOW
            context = context.cuda()
            target = target.cuda()
            outputs = model(context)
            loss = loss_fn(outputs,target.squeeze())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
            total_loss += loss.item()
            
            if print_every is not None and (batch + 1) % print_every == 0:
                print("Epoch {} || batch {} || Loss: {:.4f}".format(epoch+1, batch+1, total_loss / (batch+1)))
        
        model.eval()
        ##TODO Compute Loss on Test and Training Data
        train_loss = total_loss / (batch+1)
        test_loss = 0
        for batch_t, (context_t, target_t) in enumerate(get_cbow_batches(test_data, batch_size)):
            context_t = context_t.cuda()
            target_t = target_t.cuda()
            outputs_t = model(context_t)
            loss_t = loss_fn(outputs_t,target_t.squeeze())
            test_loss += loss_t.item()
        test_loss = test_loss / (batch_t+1)
        print("Epoch {}/{} || Train Loss: {:.4f} || Test Loss: {:.4f}".format(epoch+1, n_epoch, train_loss, test_loss))
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete.")
    return model, losses, test_losses

## Train Model
cbow_model, cbow_losses, cbow_test_losses = train_cbow(cbow_train,
                                     cbow_test,
                                     model=None,
                                     n_epoch=100,
                                     embd_size=100,
                                     context_size=CONTEXT_SIZE,
                                     batch_size=50,
                                     learning_rate=0.01,
                                     hidden_size=128,
                                     print_every=None)
# Out:
# CBOW(
#   (embedding): Embedding(65170, 100)
#   (linear1): Linear(in_features=400, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=65170, bias=True)
#   (activation): LogSoftmax(dim=-1)
# )
# Epoch 1/100 || Train Loss: 8.0343 || Test Loss: 7.2390
# Epoch 2/100 || Train Loss: 7.0282 || Test Loss: 6.8852
# Epoch 3/100 || Train Loss: 6.7647 || Test Loss: 6.7197
# Epoch 4/100 || Train Loss: 6.6104 || Test Loss: 6.6168
# Epoch 5/100 || Train Loss: 6.5005 || Test Loss: 6.5448
# Epoch 6/100 || Train Loss: 6.4138 || Test Loss: 6.4919
# Epoch 7/100 || Train Loss: 6.3418 || Test Loss: 6.4446
# Epoch 8/100 || Train Loss: 6.2788 || Test Loss: 6.4109
# Epoch 9/100 || Train Loss: 6.2227 || Test Loss: 6.3809
# Epoch 10/100 || Train Loss: 6.1715 || Test Loss: 6.3558
# Epoch 11/100 || Train Loss: 6.1245 || Test Loss: 6.3322
# Epoch 12/100 || Train Loss: 6.0800 || Test Loss: 6.3135
# Epoch 13/100 || Train Loss: 6.0383 || Test Loss: 6.2967
# Epoch 14/100 || Train Loss: 5.9981 || Test Loss: 6.2818
# Epoch 15/100 || Train Loss: 5.9595 || Test Loss: 6.2675
# Epoch 16/100 || Train Loss: 5.9226 || Test Loss: 6.2579
# Epoch 17/100 || Train Loss: 5.8864 || Test Loss: 6.2459
# Epoch 18/100 || Train Loss: 5.8516 || Test Loss: 6.2380
# Epoch 19/100 || Train Loss: 5.8174 || Test Loss: 6.2285
# Epoch 20/100 || Train Loss: 5.7837 || Test Loss: 6.2219
# Epoch 21/100 || Train Loss: 5.7512 || Test Loss: 6.2158
# Epoch 22/100 || Train Loss: 5.7186 || Test Loss: 6.2125
# Epoch 23/100 || Train Loss: 5.6871 || Test Loss: 6.2113
# Epoch 24/100 || Train Loss: 5.6553 || Test Loss: 6.2052
# Epoch 25/100 || Train Loss: 5.6245 || Test Loss: 6.2102
# Epoch 26/100 || Train Loss: 5.5937 || Test Loss: 6.2009
# Epoch 27/100 || Train Loss: 5.5633 || Test Loss: 6.1984
# Epoch 28/100 || Train Loss: 5.5332 || Test Loss: 6.2004
# Epoch 29/100 || Train Loss: 5.5032 || Test Loss: 6.2039
# Epoch 30/100 || Train Loss: 5.4732 || Test Loss: 6.2007
# Epoch 31/100 || Train Loss: 5.4440 || Test Loss: 6.2108
# Epoch 32/100 || Train Loss: 5.4145 || Test Loss: 6.2035
# Epoch 33/100 || Train Loss: 5.3853 || Test Loss: 6.2080
# Epoch 34/100 || Train Loss: 5.3567 || Test Loss: 6.2126
# Epoch 35/100 || Train Loss: 5.3282 || Test Loss: 6.2183
# Epoch 36/100 || Train Loss: 5.2996 || Test Loss: 6.2224
# Epoch 37/100 || Train Loss: 5.2713 || Test Loss: 6.2231
# Epoch 38/100 || Train Loss: 5.2434 || Test Loss: 6.2453
# Epoch 39/100 || Train Loss: 5.2155 || Test Loss: 6.2419
# Epoch 40/100 || Train Loss: 5.1879 || Test Loss: 6.2452
# Epoch 41/100 || Train Loss: 5.1607 || Test Loss: 6.2495
# Epoch 42/100 || Train Loss: 5.1336 || Test Loss: 6.2687
# Epoch 43/100 || Train Loss: 5.1067 || Test Loss: 6.2631
# Epoch 44/100 || Train Loss: 5.0802 || Test Loss: 6.2764
# Epoch 45/100 || Train Loss: 5.0538 || Test Loss: 6.2873
# Epoch 46/100 || Train Loss: 5.0277 || Test Loss: 6.2988
# Epoch 47/100 || Train Loss: 5.0017 || Test Loss: 6.3027
# Epoch 48/100 || Train Loss: 4.9767 || Test Loss: 6.3045
# Epoch 49/100 || Train Loss: 4.9516 || Test Loss: 6.3157
# Epoch 50/100 || Train Loss: 4.9267 || Test Loss: 6.3286
# Epoch 51/100 || Train Loss: 4.9020 || Test Loss: 6.3407
# Epoch 52/100 || Train Loss: 4.8775 || Test Loss: 6.3572
# Epoch 53/100 || Train Loss: 4.8537 || Test Loss: 6.3624
# Epoch 54/100 || Train Loss: 4.8300 || Test Loss: 6.3791
# Epoch 55/100 || Train Loss: 4.8067 || Test Loss: 6.3740
# Epoch 56/100 || Train Loss: 4.7840 || Test Loss: 6.3964
# Epoch 57/100 || Train Loss: 4.7614 || Test Loss: 6.3995
# Epoch 58/100 || Train Loss: 4.7391 || Test Loss: 6.4143
# Epoch 59/100 || Train Loss: 4.7166 || Test Loss: 6.4264
# Epoch 60/100 || Train Loss: 4.6953 || Test Loss: 6.4451
# Epoch 61/100 || Train Loss: 4.6740 || Test Loss: 6.4385
# Epoch 62/100 || Train Loss: 4.6532 || Test Loss: 6.4635
# Epoch 63/100 || Train Loss: 4.6328 || Test Loss: 6.4674
# Epoch 64/100 || Train Loss: 4.6119 || Test Loss: 6.4858
# Epoch 65/100 || Train Loss: 4.5923 || Test Loss: 6.4948
# Epoch 66/100 || Train Loss: 4.5731 || Test Loss: 6.4970
# Epoch 67/100 || Train Loss: 4.5543 || Test Loss: 6.5103
# Epoch 68/100 || Train Loss: 4.5353 || Test Loss: 6.5236
# Epoch 69/100 || Train Loss: 4.5174 || Test Loss: 6.5326
# Epoch 70/100 || Train Loss: 4.4998 || Test Loss: 6.5392
# Epoch 71/100 || Train Loss: 4.4825 || Test Loss: 6.5691
# Epoch 72/100 || Train Loss: 4.4658 || Test Loss: 6.5720
# Epoch 73/100 || Train Loss: 4.4495 || Test Loss: 6.5624
# Epoch 74/100 || Train Loss: 4.4329 || Test Loss: 6.5926
# Epoch 75/100 || Train Loss: 4.4176 || Test Loss: 6.5982
# Epoch 76/100 || Train Loss: 4.4026 || Test Loss: 6.6148
# Epoch 77/100 || Train Loss: 4.3884 || Test Loss: 6.6059
# Epoch 78/100 || Train Loss: 4.3740 || Test Loss: 6.6473
# Epoch 79/100 || Train Loss: 4.3600 || Test Loss: 6.6287
# Epoch 80/100 || Train Loss: 4.3472 || Test Loss: 6.6594
# Epoch 81/100 || Train Loss: 4.3349 || Test Loss: 6.6603
# Epoch 82/100 || Train Loss: 4.3229 || Test Loss: 6.6558
# Epoch 83/100 || Train Loss: 4.3110 || Test Loss: 6.6777
# Epoch 84/100 || Train Loss: 4.2998 || Test Loss: 6.6953
# Epoch 85/100 || Train Loss: 4.2889 || Test Loss: 6.6731
# Epoch 86/100 || Train Loss: 4.2784 || Test Loss: 6.7419
# Epoch 87/100 || Train Loss: 4.2680 || Test Loss: 6.7009
# Epoch 88/100 || Train Loss: 4.2575 || Test Loss: 6.7032
# Epoch 89/100 || Train Loss: 4.2485 || Test Loss: 6.7050
# Epoch 90/100 || Train Loss: 4.2395 || Test Loss: 6.7252
# Epoch 91/100 || Train Loss: 4.2303 || Test Loss: 6.7376
# Epoch 92/100 || Train Loss: 4.2216 || Test Loss: 6.7218
# Epoch 93/100 || Train Loss: 4.2132 || Test Loss: 6.7342
# Epoch 94/100 || Train Loss: 4.2047 || Test Loss: 6.7374
# Epoch 95/100 || Train Loss: 4.1968 || Test Loss: 6.7411
# Epoch 96/100 || Train Loss: 4.1897 || Test Loss: 6.7539
# Epoch 97/100 || Train Loss: 4.1825 || Test Loss: 6.7558
# Epoch 98/100 || Train Loss: 4.1753 || Test Loss: 6.7701
# Epoch 99/100 || Train Loss: 4.1680 || Test Loss: 6.7592
# Epoch 100/100 || Train Loss: 4.1615 || Test Loss: 6.7732
# Training Complete.

# %%
def train_cbow(train_data,
               test_data,
               model=None,
               n_epoch=100,
               embd_size=100,
               learning_rate=0.01,
               context_size=CONTEXT_SIZE,
               batch_size=50,
               hidden_size=128,
               print_every=None,
               random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Batch size
    batch_size = min(batch_size, len(train_data))
    ## Initialize New Model if Not Using Existing
    if model is None:
        model = CBOW(vocab_size, embd_size, context_size, hidden_size)
    ## GPU
    gpu_avail = torch.cuda.is_available()
    if gpu_avail:
        model = model.cuda()
    ## Show the Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate loss function
    loss_fn = nn.NLLLoss()
    ## Cache for Loss Values
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        model.train()
        for batch, (context, target) in enumerate(get_cbow_batches(train_data, batch_size)):
            ##TODO implement training procedure for CBOW
            context = context.cuda()
            target = target.cuda()
            outputs = model(context)
            loss = loss_fn(outputs,target.squeeze())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
            total_loss += loss.item()
            
            if print_every is not None and (batch + 1) % print_every == 0:
                print("Epoch {} || batch {} || Loss: {:.4f}".format(epoch+1, batch+1, total_loss / (batch+1)))
        
        model.eval()
        ##TODO Compute Loss on Test and Training Data
        train_loss = total_loss / (batch+1)
        test_loss = 0
        for batch_t, (context_t, target_t) in enumerate(get_cbow_batches(test_data, batch_size)):
            context_t = context_t.cuda()
            target_t = target_t.cuda()
            outputs_t = model(context_t)
            loss_t = loss_fn(outputs_t,target_t.squeeze())
            test_loss += loss_t.item()
        test_loss = test_loss / (batch_t+1)
        print("Epoch {}/{} || Train Loss: {:.4f} || Test Loss: {:.4f}".format(epoch+1, n_epoch, train_loss, test_loss))
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete.")
    return model, losses, test_losses

## Train Model
cbow_model, cbow_losses, cbow_test_losses = train_cbow(cbow_train,
                                     cbow_test,
                                     model=None,
                                     n_epoch=100,
                                     embd_size=100,
                                     context_size=CONTEXT_SIZE,
                                     batch_size=50,
                                     learning_rate=0.01,
                                     hidden_size=128,
                                     print_every=None)
# Out:
# CBOW(
#   (embedding): Embedding(65170, 100)
#   (linear1): Linear(in_features=400, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=65170, bias=True)
#   (activation): LogSoftmax(dim=-1)
# )
# Epoch 1/100 || Train Loss: 8.0328 || Test Loss: 7.2378
# Epoch 2/100 || Train Loss: 7.0281 || Test Loss: 6.8853
# Epoch 3/100 || Train Loss: 6.7644 || Test Loss: 6.7211
# Epoch 4/100 || Train Loss: 6.6104 || Test Loss: 6.6177
# Epoch 5/100 || Train Loss: 6.5002 || Test Loss: 6.5457
# Epoch 6/100 || Train Loss: 6.4136 || Test Loss: 6.4891
# Epoch 7/100 || Train Loss: 6.3416 || Test Loss: 6.4474
# Epoch 8/100 || Train Loss: 6.2789 || Test Loss: 6.4093
# Epoch 9/100 || Train Loss: 6.2226 || Test Loss: 6.3814
# Epoch 10/100 || Train Loss: 6.1718 || Test Loss: 6.3533
# Epoch 11/100 || Train Loss: 6.1241 || Test Loss: 6.3325
# Epoch 12/100 || Train Loss: 6.0798 || Test Loss: 6.3134
# Epoch 13/100 || Train Loss: 6.0377 || Test Loss: 6.2962
# Epoch 14/100 || Train Loss: 5.9974 || Test Loss: 6.2821
# Epoch 15/100 || Train Loss: 5.9590 || Test Loss: 6.2679
# Epoch 16/100 || Train Loss: 5.9219 || Test Loss: 6.2525
# Epoch 17/100 || Train Loss: 5.8857 || Test Loss: 6.2470
# Epoch 18/100 || Train Loss: 5.8507 || Test Loss: 6.2333
# Epoch 19/100 || Train Loss: 5.8169 || Test Loss: 6.2289
# Epoch 20/100 || Train Loss: 5.7832 || Test Loss: 6.2290
# Epoch 21/100 || Train Loss: 5.7501 || Test Loss: 6.2170
# Epoch 22/100 || Train Loss: 5.7180 || Test Loss: 6.2090
# Epoch 23/100 || Train Loss: 5.6857 || Test Loss: 6.2046
# Epoch 24/100 || Train Loss: 5.6545 || Test Loss: 6.2055
# Epoch 25/100 || Train Loss: 5.6233 || Test Loss: 6.2003
# Epoch 26/100 || Train Loss: 5.5929 || Test Loss: 6.2017
# Epoch 27/100 || Train Loss: 5.5619 || Test Loss: 6.1990
# Epoch 28/100 || Train Loss: 5.5320 || Test Loss: 6.1999
# Epoch 29/100 || Train Loss: 5.5020 || Test Loss: 6.2026
# Epoch 30/100 || Train Loss: 5.4724 || Test Loss: 6.2050
# Epoch 31/100 || Train Loss: 5.4428 || Test Loss: 6.1995
# Epoch 32/100 || Train Loss: 5.4134 || Test Loss: 6.2051
# Epoch 33/100 || Train Loss: 5.3846 || Test Loss: 6.2072
# Epoch 34/100 || Train Loss: 5.3558 || Test Loss: 6.2159
# Epoch 35/100 || Train Loss: 5.3267 || Test Loss: 6.2183
# Epoch 36/100 || Train Loss: 5.2985 || Test Loss: 6.2181
# Epoch 37/100 || Train Loss: 5.2701 || Test Loss: 6.2353
# Epoch 38/100 || Train Loss: 5.2422 || Test Loss: 6.2363
# Epoch 39/100 || Train Loss: 5.2143 || Test Loss: 6.2396
# Epoch 40/100 || Train Loss: 5.1867 || Test Loss: 6.2577
# Epoch 41/100 || Train Loss: 5.1596 || Test Loss: 6.2536
# Epoch 42/100 || Train Loss: 5.1325 || Test Loss: 6.2576
# Epoch 43/100 || Train Loss: 5.1053 || Test Loss: 6.2653
# Epoch 44/100 || Train Loss: 5.0791 || Test Loss: 6.2791
# Epoch 45/100 || Train Loss: 5.0522 || Test Loss: 6.2874
# Epoch 46/100 || Train Loss: 5.0263 || Test Loss: 6.2943
# Epoch 47/100 || Train Loss: 5.0009 || Test Loss: 6.3067
# Epoch 48/100 || Train Loss: 4.9754 || Test Loss: 6.3173
# Epoch 49/100 || Train Loss: 4.9501 || Test Loss: 6.3253
# Epoch 50/100 || Train Loss: 4.9251 || Test Loss: 6.3409
# Epoch 51/100 || Train Loss: 4.9005 || Test Loss: 6.3427
# Epoch 52/100 || Train Loss: 4.8765 || Test Loss: 6.3530
# Epoch 53/100 || Train Loss: 4.8527 || Test Loss: 6.3602
# Epoch 54/100 || Train Loss: 4.8290 || Test Loss: 6.3634
# Epoch 55/100 || Train Loss: 4.8054 || Test Loss: 6.3794
# Epoch 56/100 || Train Loss: 4.7828 || Test Loss: 6.3915
# Epoch 57/100 || Train Loss: 4.7604 || Test Loss: 6.3941
# Epoch 58/100 || Train Loss: 4.7376 || Test Loss: 6.4168
# Epoch 59/100 || Train Loss: 4.7158 || Test Loss: 6.4256
# Epoch 60/100 || Train Loss: 4.6941 || Test Loss: 6.4408
# Epoch 61/100 || Train Loss: 4.6730 || Test Loss: 6.4400
# Epoch 62/100 || Train Loss: 4.6520 || Test Loss: 6.4585
# Epoch 63/100 || Train Loss: 4.6314 || Test Loss: 6.4636
# Epoch 64/100 || Train Loss: 4.6110 || Test Loss: 6.4995
# Epoch 65/100 || Train Loss: 4.5916 || Test Loss: 6.4864
# Epoch 66/100 || Train Loss: 4.5719 || Test Loss: 6.5104
# Epoch 67/100 || Train Loss: 4.5531 || Test Loss: 6.5091
# Epoch 68/100 || Train Loss: 4.5347 || Test Loss: 6.5220
# Epoch 69/100 || Train Loss: 4.5165 || Test Loss: 6.5446
# Epoch 70/100 || Train Loss: 4.4991 || Test Loss: 6.5457
# Epoch 71/100 || Train Loss: 4.4817 || Test Loss: 6.5830
# Epoch 72/100 || Train Loss: 4.4647 || Test Loss: 6.5768
# Epoch 73/100 || Train Loss: 4.4481 || Test Loss: 6.5806
# Epoch 74/100 || Train Loss: 4.4320 || Test Loss: 6.5769
# Epoch 75/100 || Train Loss: 4.4166 || Test Loss: 6.5902
# Epoch 76/100 || Train Loss: 4.4013 || Test Loss: 6.6022
# Epoch 77/100 || Train Loss: 4.3874 || Test Loss: 6.6257
# Epoch 78/100 || Train Loss: 4.3733 || Test Loss: 6.6294
# Epoch 79/100 || Train Loss: 4.3600 || Test Loss: 6.6307
# Epoch 80/100 || Train Loss: 4.3465 || Test Loss: 6.6404
# Epoch 81/100 || Train Loss: 4.3342 || Test Loss: 6.6464
# Epoch 82/100 || Train Loss: 4.3216 || Test Loss: 6.6574
# Epoch 83/100 || Train Loss: 4.3103 || Test Loss: 6.6854
# Epoch 84/100 || Train Loss: 4.2991 || Test Loss: 6.6792
# Epoch 85/100 || Train Loss: 4.2883 || Test Loss: 6.6736
# Epoch 86/100 || Train Loss: 4.2773 || Test Loss: 6.6843
# Epoch 87/100 || Train Loss: 4.2676 || Test Loss: 6.6918
# Epoch 88/100 || Train Loss: 4.2575 || Test Loss: 6.7127
# Epoch 89/100 || Train Loss: 4.2483 || Test Loss: 6.7355
# Epoch 90/100 || Train Loss: 4.2392 || Test Loss: 6.7048
# Epoch 91/100 || Train Loss: 4.2297 || Test Loss: 6.7226
# Epoch 92/100 || Train Loss: 4.2217 || Test Loss: 6.7279
# Epoch 93/100 || Train Loss: 4.2133 || Test Loss: 6.7299
# Epoch 94/100 || Train Loss: 4.2052 || Test Loss: 6.7325
# Epoch 95/100 || Train Loss: 4.1976 || Test Loss: 6.7428
# Epoch 96/100 || Train Loss: 4.1900 || Test Loss: 6.7438
# Epoch 97/100 || Train Loss: 4.1822 || Test Loss: 6.7539
# Epoch 98/100 || Train Loss: 4.1755 || Test Loss: 6.7724
# Epoch 99/100 || Train Loss: 4.1685 || Test Loss: 6.8000
# Epoch 100/100 || Train Loss: 4.1617 || Test Loss: 6.7666
# Training Complete.

# %%
## Test Predictive Accuracy
def test_cbow(test_data, model, sample_size=None, seed=42, use_gpu=False):
    ## Random State
    np.random.seed(seed)
    ## Count Correct Answers
    correct_ct = 0
    ## Downsample if Desired (To Save Time)
    if sample_size is None:
        sample = test_data
    else:
        sample = np.random.choice(len(test_data), sample_size, replace=False)
        sample = [test_data[s] for s in sample]
    ## Evaluate
    model.eval()
    for ctx_var, target in get_cbow_batches(sample, 1):
        if use_gpu:
            ctx_var = ctx_var.cuda()
        model.zero_grad()
        log_probs = model(ctx_var)
        if use_gpu:
            log_probs = log_probs.cpu()
        #_, predicted = torch.max(log_probs[0], 1)
        predicted = torch.argmax(log_probs[0])
        if torch.eq(predicted, target[0]):
            correct_ct += 1
            
    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(sample)*100, correct_ct, len(sample)))

test_cbow(cbow_train, cbow_model, sample_size=min(5000, len(cbow_train)), use_gpu=torch.cuda.is_available())
test_cbow(cbow_test, cbow_model, sample_size=min(5000, len(cbow_test)), use_gpu=torch.cuda.is_available())
# Out:
# Accuracy: 28.6% (1428/5000)
# Accuracy: 18.6% (930/5000)

# %%
showPlot('CBOW Losses',cbow_losses,cbow_test_losses)

# %%
#save the model
PATH = "gdrive/MyDrive/'cbow_model_large.pt'"
torch.save(cbow_model, PATH)
#load
#the_model = torch.load(PATH)

# %% [markdown]
# ###skip-gram

# %%
# Tuple of a word (the target) to a word (a context word)
CONTEXT_SIZE = 2
def create_skipgram_dataset(documents, context_size, k_negative=5):
    data = []
    for document in documents:
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        for i in range(context_size, len(document) - context_size):
            word_set = set()
            for j in range(1, context_size+1):
                data.append((document[i], document[i-j], 1))
                data.append((document[i], document[i+j], 1))

            ##TODO: Implement negative sampling
            for _ in range(k_negative):
                rand_id = random.randint(0, vocab_size-1)
                if not rand_id in word_set:
                    data.append((document[i], i2w[rand_id], 0))
    return data

## Create Datasets
skipgram_train = create_skipgram_dataset(documents_train, context_size=CONTEXT_SIZE, k_negative=5)
skipgram_test = create_skipgram_dataset(documents_test, context_size=CONTEXT_SIZE, k_negative=5)

## Show Samples
print('skipgram sample', skipgram_train[:10])
# Out:
# skipgram sample [('the', 'EOS', 1), ('the', 'liberals', 1), ('the', 'EOS', 1), ('the', 'tend', 1), ('the', 'fencesitters', 0), ('the', 'ramses', 0), ('the', 'namibia', 0), ('the', 'sweeps', 0), ('the', 'hazirliklari', 0), ('liberals', 'the', 1)]

# %%
## Mount Google Drive Data (If using Google Colaboratory)
try:
    from google.colab import drive
    drive.mount('/content/gdrive')
except:
    print("Mounting Failed.")
# Out:
# Mounted at /content/gdrive

# %%
def train_skipgram(train_data,
                   test_data,
                   model=None,
                   n_epoch=100,
                   learning_rate=0.01,
                   batch_size=100,
                   embd_size=128,
                   print_every_step=None,
                   print_every_epoch=1,
                   random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Initialize Model
    if model is None:
        model = SkipGram(vocab_size, embd_size)
    ## Put on GPU
    if torch.cuda.is_available():
        model = model.cuda()
    ## Show Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate Loss Function
    loss_fn = nn.BCELoss()
    ## Loss Cache
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        for step, (in_w_var, out_w_var, target_t) in enumerate(get_sgram_batches(train_data, batch_size)):
            #TODO implement training procedure for SkipGram
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()

            model.zero_grad()
            probs = model(in_w_var, out_w_var)
            loss = loss_fn(probs, target_t.squeeze())
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            
            if print_every_step is not None and (step + 1) % print_every_step == 0:
                print("Epoch {} || Step {}/{} || Loss: {:.4f}".format(epoch+1, step+1, len(train_data), (total_loss / step+1)))
            
        if print_every_epoch is not None and (epoch + 1) % print_every_epoch == 0:
            print("Epoch {}/{} || Loss: {:.4f}".format(epoch+1, n_epoch, total_loss / step+1))
        model.eval()
        ##TODO Compute Losses
        train_loss = total_loss / (step+1)
        test_loss = 0
        for step_t, (in_w_var1, out_w_var1, target_t1) in enumerate(get_sgram_batches(test_data, batch_size)):
            #TODO implement training procedure for SkipGram
            in_w_var1 = in_w_var1.cuda()
            out_w_var1 = out_w_var1.cuda()
            target_t1 = target_t1.cuda()

            probs1 = model(in_w_var1, out_w_var1)
            loss_t = loss_fn(probs1, target_t1.squeeze())
            test_loss += loss_t.item()
        test_loss = test_loss / (step_t+1)
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete")
    return model, losses, test_losses

## Fit Model
sg_model, sg_losses, sg_tloss = train_skipgram(skipgram_train,
                                     skipgram_test,
                                     n_epoch=100,
                                     learning_rate=0.01,
                                     batch_size=100,
                                     embd_size=128,
                                     print_every_step=None,
                                     print_every_epoch=1)
# Out:
# SkipGram(
#   (embedding): Embedding(65170, 128)
# )
# Epoch 1/100 || Loss: 7.2432
# Epoch 2/100 || Loss: 6.1211
# Epoch 3/100 || Loss: 5.7049
# Epoch 4/100 || Loss: 5.4461
# Epoch 5/100 || Loss: 5.2564
# Epoch 6/100 || Loss: 5.1082
# Epoch 7/100 || Loss: 4.9859
# Epoch 8/100 || Loss: 4.8829
# Epoch 9/100 || Loss: 4.7948
# Epoch 10/100 || Loss: 4.7155
# Epoch 11/100 || Loss: 4.6446
# Epoch 12/100 || Loss: 4.5808
# Epoch 13/100 || Loss: 4.5226
# Epoch 14/100 || Loss: 4.4686
# Epoch 15/100 || Loss: 4.4194
# Epoch 16/100 || Loss: 4.3721
# Epoch 17/100 || Loss: 4.3293
# Epoch 18/100 || Loss: 4.2875
# Epoch 19/100 || Loss: 4.2485
# Epoch 20/100 || Loss: 4.2111
# Epoch 21/100 || Loss: 4.1753
# Epoch 22/100 || Loss: 4.1415
# Epoch 23/100 || Loss: 4.1090
# Epoch 24/100 || Loss: 4.0776
# Epoch 25/100 || Loss: 4.0472
# Epoch 26/100 || Loss: 4.0185
# Epoch 27/100 || Loss: 3.9906
# Epoch 28/100 || Loss: 3.9629
# Epoch 29/100 || Loss: 3.9367
# Epoch 30/100 || Loss: 3.9108
# Epoch 31/100 || Loss: 3.8855
# Epoch 32/100 || Loss: 3.8612
# Epoch 33/100 || Loss: 3.8382
# Epoch 34/100 || Loss: 3.8159
# Epoch 35/100 || Loss: 3.7938
# Epoch 36/100 || Loss: 3.7714
# Epoch 37/100 || Loss: 3.7504
# Epoch 38/100 || Loss: 3.7298
# Epoch 39/100 || Loss: 3.7098
# Epoch 40/100 || Loss: 3.6899
# Epoch 41/100 || Loss: 3.6707
# Epoch 42/100 || Loss: 3.6516
# Epoch 43/100 || Loss: 3.6329
# Epoch 44/100 || Loss: 3.6146
# Epoch 45/100 || Loss: 3.5964
# Epoch 46/100 || Loss: 3.5786
# Epoch 47/100 || Loss: 3.5618
# Epoch 48/100 || Loss: 3.5450
# Epoch 49/100 || Loss: 3.5288
# Epoch 50/100 || Loss: 3.5121
# Epoch 51/100 || Loss: 3.4963
# Epoch 52/100 || Loss: 3.4806
# Epoch 53/100 || Loss: 3.4656
# Epoch 54/100 || Loss: 3.4503
# Epoch 55/100 || Loss: 3.4358
# Epoch 56/100 || Loss: 3.4209
# Epoch 57/100 || Loss: 3.4065
# Epoch 58/100 || Loss: 3.3922
# Epoch 59/100 || Loss: 3.3783
# Epoch 60/100 || Loss: 3.3648
# Epoch 61/100 || Loss: 3.3518
# Epoch 62/100 || Loss: 3.3385
# Epoch 63/100 || Loss: 3.3256
# Epoch 64/100 || Loss: 3.3128
# Epoch 65/100 || Loss: 3.3006
# Epoch 66/100 || Loss: 3.2881
# Epoch 67/100 || Loss: 3.2756
# Epoch 68/100 || Loss: 3.2636
# Epoch 69/100 || Loss: 3.2515
# Epoch 70/100 || Loss: 3.2396
# Epoch 71/100 || Loss: 3.2277
# Epoch 72/100 || Loss: 3.2163
# Epoch 73/100 || Loss: 3.2049
# Epoch 74/100 || Loss: 3.1937
# Epoch 75/100 || Loss: 3.1829
# Epoch 76/100 || Loss: 3.1720
# Epoch 77/100 || Loss: 3.1610
# Epoch 78/100 || Loss: 3.1503
# Epoch 79/100 || Loss: 3.1396
# Epoch 80/100 || Loss: 3.1291
# Epoch 81/100 || Loss: 3.1187
# Epoch 82/100 || Loss: 3.1085
# Epoch 83/100 || Loss: 3.0983
# Epoch 84/100 || Loss: 3.0881
# Epoch 85/100 || Loss: 3.0785
# Epoch 86/100 || Loss: 3.0691
# Epoch 87/100 || Loss: 3.0595
# Epoch 88/100 || Loss: 3.0499
# Epoch 89/100 || Loss: 3.0405
# Epoch 90/100 || Loss: 3.0315
# Epoch 91/100 || Loss: 3.0224
# Epoch 92/100 || Loss: 3.0134
# Epoch 93/100 || Loss: 3.0045
# Epoch 94/100 || Loss: 2.9959
# Epoch 95/100 || Loss: 2.9871
# Epoch 96/100 || Loss: 2.9784
# Epoch 97/100 || Loss: 2.9702
# Epoch 98/100 || Loss: 2.9617
# Epoch 99/100 || Loss: 2.9530
# Epoch 100/100 || Loss: 2.9448
# Training Complete

# %%
## Plot Losses
showPlot('SkipGram Losses', sg_losses,sg_tloss)

# %%
## Evaluate Accuracy
def test_skipgram(test_data, model):
    correct_ct = 0
    for in_w_var, out_w_var, target_t in get_sgram_batches(test_data, 1000):

        if torch.cuda.is_available():
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()
        probs = model(in_w_var, out_w_var)
        predicted = (probs > 0.5)
        correct_ct += torch.sum(torch.eq(predicted[0], target_t))

    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(test_data)*100, correct_ct, len(test_data)))

test_skipgram(skipgram_train, sg_model)
test_skipgram(skipgram_test, sg_model)
# Out:
# Accuracy: 48.6% (4131093/8496351)
# Accuracy: 48.4% (1368728/2827107)

# %%
#save the model
PATH = "gdrive/MyDrive/'sg_model_large.pt'"
torch.save(sg_model, PATH)
#load
#the_model = torch.load(PATH)

# %% [markdown]
# ###Evaluate Semantic Similarity for the large dataset

# %%
#Load model
PATH1 = "gdrive/MyDrive/'sg_model_large.pt'"
PATH2 = "gdrive/MyDrive/'cbow_model_large.pt'"
sg_large_model = torch.load(PATH1,map_location=torch.device('cpu'))
cbow_large_model = torch.load(PATH2,map_location=torch.device('cpu'))

# %%
## Evaluation for The large dataset embeddings
get_similarity(cbow_large_model.embedding, w2i, "friendship","racer")
show_similar_terms(cbow_large_model.embedding, w2i, i2w, "friendship")

## Evaluation for The large dataset embeddings
get_similarity(sg_large_model.embedding, w2i, "friendship","racer")
show_similar_terms(sg_large_model.embedding, w2i, i2w, "friendship")
# Out:
# friendship racer 1.1169114112854004
# ['maybee', 'opel', 'rival', 'unix', 'cccp', 'kiribati', 'chlamydomonas', 'sakic', 'colora', 'mmaxqbcbfuxdzlp']
# friendship racer 1.0530095100402832
# ['slvruc', 'evy', 'zheleznovodsk', 'kisio', 'lawshminpit', 'prepackaged', 'darkhorse', 'slaughter', 'polymorphonuclear', 'facelift']
